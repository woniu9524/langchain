# %% [markdown]
# ---
# sidebar_label: __ModuleName__
# ---

# %% [markdown]
# # __ModuleName__Loader
#
# - TODO: 确保 API 参考链接正确。
#
# 本笔记本提供了使用 __ModuleName__ [文档加载器](https://python.langchain.com/docs/concepts/document_loaders) 的快速入门指南。有关 __ModuleName__Loader 所有功能和配置的详细文档，请访问[API 参考](https://python.langchain.com/v0.2/api_reference/community/document_loaders/langchain_community.document_loaders.__module_name___loader.__ModuleName__Loader.html)。
#
# - TODO: 添加任何其他相关链接，例如有关底层 API 的信息等。
#
# ## 概述
# ### 集成详情
#
# - TODO: 填写表格功能。
# - TODO: 如果不相关，请删除 JS 支持链接，否则请确保链接正确。
# - TODO: 确保 API 参考链接正确。
#
# | 类 | 包 | 本地 | 可序列化 | [JS 支持](https://js.langchain.com/docs/integrations/document_loaders/web_loaders/__module_name___loader)|
# | :--- | :--- | :---: | :---: |  :---: |
# | [__ModuleName__Loader](https://python.langchain.com/v0.2/api_reference/community/document_loaders/langchain_community.document_loaders.__module_name__loader.__ModuleName__Loader.html) | [langchain_community](https://api.python.langchain.com/en/latest/community_api_reference.html) | ✅/❌ | beta/❌ | ✅/❌ |
# ### 加载器功能
# | 源 | 文档延迟加载 | 原生异步支持
# | :---: | :---: | :---: |
# | __ModuleName__Loader | ✅/❌ | ✅/❌ |
#
# ## 设置
#
# - TODO: 更新相关信息。
#
# 要访问 __ModuleName__ 文档加载器，您需要安装 `__package_name__` 集成包，并创建一个 **ModuleName** 账户并获取 API 密钥。
#
# ### 凭证
#
# - TODO: 更新相关信息。
#
# 前往 (TODO: 链接) 注册 __ModuleName__ 并生成 API 密钥。完成此操作后，设置 __MODULE_NAME___API_KEY 环境变量：

# %%
import getpass
import os

os.environ["__MODULE_NAME___API_KEY"] = getpass.getpass("Enter your __ModuleName__ API key: ")

# %% [markdown]
# 要启用模型调用的自动化跟踪，请设置您的 [LangSmith](https://docs.smith.langchain.com/) API 密钥：

# %%
# os.environ["LANGSMITH_API_KEY"] = getpass.getpass("Enter your LangSmith API key: ")
# os.environ["LANGSMITH_TRACING"] = "true"

# %% [markdown]
# ### 安装
#
# 安装 **langchain_community**。
#
# - TODO：添加任何其他必需的包

# %%
# %pip install -qU langchain_community

# %% [markdown]
# ## 初始化
#
# 现在我们可以实例化我们的模型对象并加载文档了：
#
# - TODO：使用相关参数更新模型实例化。

# %%
from langchain_community.document_loaders import __ModuleName__Loader

loader = __ModuleName__Loader(
    # required params = ...
    # optional params = ...
)

# %% [markdown]
# ## 加载
#
# - TODO: 运行单元格以展示加载功能

# %%
docs = loader.load()
docs[0]

# %%
print(docs[0].metadata)

# %% [markdown]
# ## 懒加载
#
# - TODO：运行单元格以展示懒加载功能。如果未实现懒加载，请删除此项。

# %%
page = []
for doc in loader.lazy_load():
    page.append(doc)
    if len(page) >= 10:
        # do some paged operation, e.g.
        # index.upsert(page)

        page = []

# %% [markdown]
# ## TODO：此文档加载器特有的任何功能
#
# 例如，为不同的加载行为使用特定的配置。如果无关则删除。

# %% [markdown]
# ## API 参考
#
# 有关 __ModuleName__Loader 所有功能和配置的详细文档，请参阅 API 参考：https://python.langchain.com/v0.2/api_reference/community/document_loaders/langchain_community.document_loaders.__module_name___loader.__ModuleName__Loader.html
