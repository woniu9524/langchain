# %% [raw]
# ---
# sidebar_label: __ModuleName__
# ---

# %% [markdown]
# # __ModuleName__LLM
#
# - [ ] TODO: 确保 API 参考链接正确
#
# 这将帮助您开始使用 LangChain 的 __ModuleName__ 补全模型（LLM）。有关 `__ModuleName__LLM` 功能和配置选项的详细文档，请参阅 [API 参考](https://api.python.langchain.com/en/latest/llms/__module_name__.llms.__ModuleName__LLM.html)。
#
# ## 概览
# ### 集成详情
#
# - TODO: 填写表格功能。
# - TODO: 如果不相关，请删除 JS 支持链接，否则请确保链接正确。
# - TODO: 确保 API 参考链接正确。
#
# | 类 | 包 | 本地 | 可序列化 | [JS 支持](https://js.langchain.com/docs/integrations/llms/__package_name_short_snake__) | 包下载 | 包最新版本 |
# | :--- | :--- | :---: | :---: |  :---: | :---: | :---: |
# | [__ModuleName__LLM](https://api.python.langchain.com/en/latest/llms/__module_name__.llms.__ModuleName__LLM.html) | [__package_name__](https://api.python.langchain.com/en/latest/__package_name_short_snake___api_reference.html) | ✅/❌ | beta/❌ | ✅/❌ | ![PyPI - Downloads](https://img.shields.io/pypi/dm/__package_name__?style=flat-square&label=%20) | ![PyPI - Version](https://img.shields.io/pypi/v/__package_name__?style=flat-square&label=%20) |
#
# ## 设置
#
# - TODO: 更新相关信息。
#
# 要访问 __ModuleName__ 模型，您需要创建一个 __ModuleName__ 账户，获取 API 密钥，并安装 `__package_name__` 集成包。
#
# ### 凭证
#
# - TODO: 更新相关信息。
#
# 前往 (TODO: 链接) 注册 __ModuleName__ 并生成 API 密钥。完成此操作后，请设置 __MODULE_NAME___API_KEY 环境变量：

# %%
import getpass
import os

if not os.getenv("__MODULE_NAME___API_KEY"):
    os.environ["__MODULE_NAME___API_KEY"] = getpass.getpass("Enter your __ModuleName__ API key: ")

# %% [markdown]
# 要启用模型调用的自动化跟踪，请设置您的 [LangSmith](https://docs.smith.langchain.com/) API 密钥：

# %%
# os.environ["LANGSMITH_TRACING"] = "true"
# os.environ["LANGSMITH_API_KEY"] = getpass.getpass("Enter your LangSmith API key: ")

# %% [markdown]
# ### 安装
#
# LangChain __ModuleName__ 集成位于 `__package_name__` 包中：

# %%
# %pip install -qU __package_name__

# %% [markdown]
# ## 实例化
#
# 现在我们可以实例化我们的模型对象并生成聊天补全：
#
# - TODO：使用相关参数更新模型实例化。

# %%
from __module_name__ import __ModuleName__LLM

llm = __ModuleName__LLM(
    model="model-name",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %% [markdown]
# ## 调用
#
# - [ ] TODO: 运行单元格以便查看输出。

# %%
input_text = "__ModuleName__ is an AI company that "

completion = llm.invoke(input_text)
completion

# %% [markdown]
# ## 链式调用
#
# 我们可以像这样将我们的完成模型与提示模板进行[链式调用](/docs/how_to/sequence/)：
#
# - TODO：运行单元格以便查看输出。

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    "How to say {input} in {output_language}:\n"
)

chain = prompt | llm
chain.invoke(
    {
        "output_language": "German",
        "input": "I love programming.",
    }
)

# %% [markdown]
# ## TODO：此模型提供商的任何特定功能
#
# 例如，通过此提供商创建/使用微调模型。如果无关则删除

# %% [markdown]
# ## API 参考
#
# 有关 `__ModuleName__LLM` 所有功能和配置的详细文档，请访问 API 参考：https://api.python.langchain.com/en/latest/llms/__module_name__.llms.__ModuleName__LLM.html
