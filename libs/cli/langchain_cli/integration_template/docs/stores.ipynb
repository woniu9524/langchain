# %% [raw]
# ---
# sidebar_label: __ModuleName__ByteStore
# ---

# %% [markdown]
# # __ModuleName__ByteStore
#
# - TODO: 确保 API 参考链接正确。
#
# 这将帮助您开始使用 __ModuleName__ [键值存储](/docs/concepts/#key-value-stores)。有关 __ModuleName__ByteStore 所有功能和配置的详细文档，请参阅[API 参考](https://python.langchain.com/v0.2/api_reference/core/stores/langchain_core.stores.__module_name__ByteStore.html)。
#
# - TODO: 添加任何其他相关链接，例如有关模型、价格、上下文窗口等的信息。请参阅 https://python.langchain.com/docs/integrations/stores/in_memory/ 获取示例。
#
# ## 概述
#
# - TODO: (可选) 对底层技术/API 的简短介绍。
#
# ### 集成详情
#
# - TODO: 填写表格功能。
# - TODO: 如果 JS 支持链接不相关，请删除；否则，请确保链接正确。
# - TODO: 确保 API 参考链接正确。
#
# | 类 | 包 | 本地 | [JS 支持](https://js.langchain.com/docs/integrations/stores/_package_name_) | 包下载 | 包最新版本 |
# | :--- | :--- | :---: | :---: |  :---: | :---: |
# | [__ModuleName__ByteStore](https://api.python.langchain.com/en/latest/stores/__module_name__.stores.__ModuleName__ByteStore.html) | [__package_name__](https://api.python.langchain.com/en/latest/__package_name_short_snake___api_reference.html) | ✅/❌ | ✅/❌ | ![PyPI - Downloads](https://img.shields.io/pypi/dm/__package_name__?style=flat-square&label=%20) | ![PyPI - Version](https://img.shields.io/pypi/v/__package_name__?style=flat-square&label=%20) |
#
# ## 设置
#
# - TODO: 更新相关信息。
#
# 要创建 __ModuleName__ 字节存储，您需要创建一个 __ModuleName__ 账户，获取 API 密钥，并安装 `__package_name__` 集成包。
#
# ### 凭证
#
# - TODO: 更新相关信息，或在服务不需要任何凭证时省略。
#
# 前往 (TODO: 链接) 注册 __ModuleName__ 并生成 API 密钥。完成此操作后，设置 __MODULE_NAME___API_KEY 环境变量：

# %%
import getpass
import os

if not os.getenv("__MODULE_NAME___API_KEY"):
    os.environ["__MODULE_NAME___API_KEY"] = getpass.getpass("Enter your __ModuleName__ API key: ")

# %% [markdown]
# ### 安装
#
# LangChain 的 __ModuleName__ 集成位于 `__package_name__` 包中：

# %%
# %pip install -qU __package_name__

# %% [markdown]
# ## 实例化
#
# 现在我们可以实例化我们的字节存储：
#
# - TODO：使用相关参数更新模型实例化。

# %%
from __module_name__ import __ModuleName__ByteStore

kv_store = __ModuleName__ByteStore(
    # params...
)

# %% [markdown]
# ## 用法
#
# - TODO：运行单元格以便查看输出。
#
# 您可以使用 `mset` 方法为键设置数据，如下所示：

# %%
kv_store.mset(
    [
        ["key1", b"value1"],
        ["key2", b"value2"],
    ]
)

kv_store.mget(
    [
        "key1",
        "key2",
    ]
)

# %% [markdown]
# 您还可以使用 `mdelete` 方法删除数据：

# %%
kv_store.mdelete(
    [
        "key1",
        "key2",
    ]
)

kv_store.mget(
    [
        "key1",
        "key2",
    ]
)

# %% [markdown]
# ## TODO：此键值存储提供商的任何特定功能
#
# 例如，额外的初始化。如果无关则删除。

# %% [markdown]
# ## API 参考
#
# 有关 __ModuleName__ByteStore 的所有功能和配置的详细文档，请访问 API 参考：https://api.python.langchain.com/en/latest/stores/__module_name__.stores.__ModuleName__ByteStore.html
