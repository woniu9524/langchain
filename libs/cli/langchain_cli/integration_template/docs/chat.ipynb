# %% [raw]
# ---
# sidebar_label: __ModuleName__
# ---

# %% [markdown]
# # Chat__ModuleName__
#
# - TODO: 确保 API 参考链接正确。
#
# 这将帮助您开始使用 __ModuleName__ [聊天模型](/docs/concepts/chat_models)。有关所有 Chat__ModuleName__ 功能和配置的详细文档，请访问[API 参考](https://python.langchain.com/api_reference/__package_name_short_snake__/chat_models/__module_name__.chat_models.Chat__ModuleName__.html)。
#
# - TODO: 添加任何其他相关链接，例如有关模型、价格、上下文窗口等的信息。请参阅 https://python.langchain.com/docs/integrations/chat/openai/ 获取示例。
#
# ## 概述
# ### 集成详情
#
# - TODO: 填写表格功能。
# - TODO: 如果 JS 支持链接不相关，请删除；否则，请确保链接正确。
# - TODO: 确保 API 参考链接正确。
#
# | 类 | 包 | 本地 | 可序列化 | [JS 支持](https://js.langchain.com/docs/integrations/chat/__package_name_short_snake__) | 包下载 | 包最新 |
# | :--- | :--- | :---: | :---: |  :---: | :---: | :---: |
# | [Chat__ModuleName__](https://python.langchain.com/api_reference/__package_name_short_snake__/chat_models/__module_name__.chat_models.Chat__ModuleName__.html) | [__package_name__](https://python.langchain.com/api_reference/__package_name_short_snake__/) | ✅/❌ | beta/❌ | ✅/❌ | ![PyPI - Downloads](https://img.shields.io/pypi/dm/__package_name__?style=flat-square&label=%20) | ![PyPI - Version](https://img.shields.io/pypi/v/__package_name__?style=flat-square&label=%20) |
#
# ### 模型功能
# | [工具调用](/docs/how_to/tool_calling) | [结构化输出](/docs/how_to/structured_output/) | JSON 模式 | [图像输入](/docs/how_to/multimodal_inputs/) | 音频输入 | 视频输入 | [Token 级流式输出](/docs/how_to/chat_streaming/) | 原生异步 | [Token 使用量](/docs/how_to/chat_token_usage_tracking/) | [Logprobs](/docs/how_to/logprobs/) |
# | :---: | :---: | :---: | :---: |  :---: | :---: | :---: | :---: | :---: | :---: |
# | ✅/❌ | ✅/❌ | ✅/❌ | ✅/❌ | ✅/❌ | ✅/❌ | ✅/❌ | ✅/❌ | ✅/❌ | ✅/❌ |
#
# ## 设置
#
# - TODO: 更新相关信息。
#
# 要访问 __ModuleName__ 模型，您需要创建一个 __ModuleName__ 账户，获取 API 密钥，并安装 `__package_name__` 集成包。
#
# ### 凭据
#
# - TODO: 更新相关信息。
#
# 前往 (TODO: 链接) 注册 __ModuleName__ 并生成 API 密钥。完成此操作后，设置 __MODULE_NAME___API_KEY 环境变量：

# %%
import getpass
import os

if not os.getenv("__MODULE_NAME___API_KEY"):
    os.environ["__MODULE_NAME___API_KEY"] = getpass.getpass("Enter your __ModuleName__ API key: ")

# %% [markdown]
# 要启用模型调用的自动化跟踪，请设置您的 [LangSmith](https://docs.smith.langchain.com/) API 密钥：

# %%
# os.environ["LANGSMITH_TRACING"] = "true"
# os.environ["LANGSMITH_API_KEY"] = getpass.getpass("Enter your LangSmith API key: ")

# %% [markdown]
# ### 安装
#
# LangChain __ModuleName__ 集成位于 `__package_name__` 包中：

# %%
# %pip install -qU __package_name__

# %% [markdown]
# ## 实例化
#
# 现在我们可以实例化我们的模型对象并生成聊天补全：
#
# - TODO：使用相关参数更新模型实例化。

# %%
from __module_name__ import Chat__ModuleName__

llm = Chat__ModuleName__(
    model="model-name",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %% [markdown]
# ## 调用
#
# - TODO：运行单元格以便查看输出。

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg

# %%
print(ai_msg.content)

# %% [markdown]
# ## 链式调用
#
# 我们可以像这样将模型与提示模板进行[链式调用](/docs/how_to/sequence/)：
#
# - TODO: 运行单元格以便查看输出。

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate(
    [
        (
            "system",
            "You are a helpful assistant that translates {input_language} to {output_language}.",
        ),
        ("human", "{input}"),
    ]
)

chain = prompt | llm
chain.invoke(
    {
        "input_language": "English",
        "output_language": "German",
        "input": "I love programming.",
    }
)

# %% [markdown]
# ## TODO：此模型提供商的任何特定功能
#
# 例如，通过此提供商创建/使用微调模型。如果无关则删除。

# %% [markdown]
# ## API 参考
#
# 有关所有 Chat__ModuleName__ 功能和配置的详细文档，请访问 [API 参考](https://python.langchain.com/api_reference/__package_name_short_snake__/chat_models/__module_name__.chat_models.Chat__ModuleName__.html)
