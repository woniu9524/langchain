# %% [markdown]
# # 一行代码初始化任意模型
#
# 许多 LLM 应用允许终端用户指定他们希望应用由哪个模型提供商和模型提供支持。这需要编写一些逻辑，根据用户配置初始化不同的 [聊天模型](/docs/concepts/chat_models/)。`init_chat_model()` 辅助方法可以轻松地初始化许多不同的模型集成，而无需担心导入路径和类名。
#
# :::tip 支持的模型
#
# 有关支持的集成列表，请参阅 [init_chat_model()](https://python.langchain.com/api_reference/langchain/chat_models/langchain.chat_models.base.init_chat_model.html) API 参考。
#
# 请确保您已安装了您希望支持的任何模型提供商的 [集成包](/docs/integrations/chat/)。例如，您应该安装 `langchain-openai` 来初始化 OpenAI 模型。
#
# :::

# %%
# %pip install -qU langchain>=0.2.8 langchain-openai langchain-anthropic langchain-google-vertexai

# %% [markdown]
# ## 基本用法
#
# This guide covers the basic usage of the `react-native-image-crop-picker` library.
#
# 本指南涵盖了 `react-native-image-crop-picker` 库的基本用法。
#
# ```jsx
# import React from 'react';
# import { View, Button, Image, Alert } from 'react-native';
# import ImagePicker from 'react-native-image-crop-picker';
#
# const App = () => {
#   const pickImage = () => {
#     ImagePicker.openPicker({
#       width: 300,
#       height: 400,
#       cropping: true,
#     })
#       .then((image) => {
#         console.log(image);
#         // Handle the picked image, e.g., display it
#       })
#       .catch((error) => {
#         console.log('ImagePicker Error: ', error);
#         Alert.alert('Error', 'Could not pick image.');
#       });
#   };
#
#   const takePhoto = () => {
#     ImagePicker.openCamera({
#       width: 300,
#       height: 400,
#       cropping: true,
#     })
#       .then((image) => {
#         console.log(image);
#         // Handle the taken photo, e.g., display it
#       })
#       .catch((error) => {
#         console.log('Camera Error: ', error);
#         Alert.alert('Error', 'Could not take photo.');
#       });
#   };
#
#   return (
#     <View style={{ flex: 1, justifyContent: 'center', alignItems: 'center' }}>
#       <Button title="Pick Image from Gallery" onPress={pickImage} />
#       <Button title="Take Photo with Camera" onPress={takePhoto} />
#     </View>
#   );
# };
#
# export default App;
# ```
#
# ### `openPicker`
#
# This method opens the image picker from the device's gallery.
#
# 此方法从设备的图库中打开图片选择器。
#
# **Options:**
#
# 选项：
#
# *   `width`: The desired width of the cropped image.
#     所需裁剪图片的宽度。
# *   `height`: The desired height of the cropped image.
#     所需裁剪图片的高度。
# *   `cropping`: A boolean value to enable or disable cropping. If `true`, the user can crop the image after picking.
#     一个布尔值，用于启用或禁用裁剪。如果为 `true`，用户可以在选择图片后进行裁剪。
# *   `multiple`: A boolean value to allow picking multiple images. Defaults to `false`.
#     一个布尔值，允许选择多张图片。默认为 `false`。
# *   `mediaType`: Specifies the type of media to pick. Can be `'photo'` (default) or `'video'`.
#     指定要选择的媒体类型。可以是 `'photo'`（默认）或 `'video'`。
# *   `compressImageQuality`: The compression quality of the image (0 to 1). Defaults to 0.8.
#     图片的压缩质量（0 到 1）。默认为 0.8。
# *   `includeBase64`: If `true`, the image data will be returned as a Base64 encoded string. Defaults to `false`.
#     如果为 `true`，图片数据将作为 Base64 编码的字符串返回。默认为 `false`。
# *   `includeExif`: If `true`, EXIF data will be included in the returned image object. Defaults to `false`.
#     如果为 `true`，EXIF 数据将包含在返回的图片对象中。默认为 `false`。
# *   `cropperCircleOverlay`: If `true`, displays a circular overlay on the cropper. Defaults to `false`.
#     如果为 `true`，则在裁剪器上显示一个圆形叠加层。默认为 `false`。
# *   `freeStyleCropEnabled`: If `true`, allows free-style cropping without aspect ratio constraints. Defaults to `false`.
#     如果为 `true`，则允许自由裁剪，不受宽高比限制。默认为 `false`。
# *   `showCropGuidelines`: If `true`, shows crop guidelines on the cropper. Defaults to `true`.
#     如果为 `true`，则在裁剪器上显示裁剪指南。默认为 `true`。
# *   `hideBottomControls`: If `true`, hides the bottom controls (crop, rotate, etc.) in the cropper. Defaults to `false`.
#     如果为 `true`，则在裁剪器中隐藏底部控件（裁剪、旋转等）。默认为 `false`。
# *   `enableRotation`: If `true`, allows rotation of the image in the cropper. Defaults to `false`.
#     如果为 `true`，则允许在裁剪器中旋转图片。默认为 `false`。
# *   `compressImageUtil`: Specifies the image compression utility to use. Can be `'native'` (default) or `'ios'` (for iOS only).
#     指定要使用的图片压缩工具。可以是 `'native'`（默认）或 `'ios'`（仅限 iOS）。
# *   `smartReframe`: If `true`, enables smart reframing for cropping. Defaults to `false`.
#     如果为 `true`，则启用智能重构以进行裁剪。默认为 `false`。
# *   `forceJpg`: If `true`, forces the output image to be in JPEG format. Defaults to `false`.
#     如果为 `true`，则强制输出图片为 JPEG 格式。默认为 `false`。
# *   `compressImageIo`: If `true`, compresses the image using the `image-compressor` library. Defaults to `false`.
#     如果为 `true`，则使用 `image-compressor` 库压缩图片。默认为 `false`。
# *   `minCompressResolution`: The minimum resolution for image compression. Defaults to `{ width: 100, height: 100 }`.
#     图片压缩的最小分辨率。默认为 `{ width: 100, height: 100 }`。
# *   `compressImageUtil`: Specifies the image compression utility to use. Can be `'native'` (default) or `'ios'` (for iOS only).
#     指定要使用的图片压缩工具。可以是 `'native'`（默认）或 `'ios'`（仅限 iOS）。
# *   `useFrontCamera`: If `true`, uses the front camera by default when opening the camera. Defaults to `false`.
#     如果为 `true`，则打开相机时默认使用前置摄像头。默认为 `false`。
# *   `compressVideos`: If `true`, compresses videos. Defaults to `true`.
#     如果为 `true`，则压缩视频。默认为 `true`。
# *   `videoExportPreset`: Specifies the video export preset. Defaults to `'Passthrough'`.
#     指定视频导出预设。默认为 `'Passthrough'`。
# *   `allowAssetSelectionFromPhotoLibrary`: If `true`, allows asset selection from the photo library. Defaults to `false`.
#     如果为 `true`，则允许从照片库中选择资源。默认为 `false`。
# *   `mediaType`: Specifies the type of media to pick. Can be `'photo'` (default) or `'video'`.
#     指定要选择的媒体类型。可以是 `'photo'`（默认）或 `'video'`。
# *   `compressImageQuality`: The compression quality of the image (0 to 1). Defaults to 0.8.
#     图片的压缩质量（0 到 1）。默认为 0.8。
# *   `includeBase64`: If `true`, the image data will be returned as a Base64 encoded string. Defaults to `false`.
#     如果为 `true`，图片数据将作为 Base64 编码的字符串返回。默认为 `false`。
# *   `includeExif`: If `true`, EXIF data will be included in the returned image object. Defaults to `false`.
#     如果为 `true`，EXIF 数据将包含在返回的图片对象中。默认为 `false`。
# *   `cropperCircleOverlay`: If `true`, displays a circular overlay on the cropper. Defaults to `false`.
#     如果为 `true`，则在裁剪器上显示一个圆形叠加层。默认为 `false`。
# *   `freeStyleCropEnabled`: If `true`, allows free-style cropping without aspect ratio constraints. Defaults to `false`.
#     如果为 `true`，则允许自由裁剪，不受宽高比限制。默认为 `false`。
# *   `showCropGuidelines`: If `true`, shows crop guidelines on the cropper. Defaults to `true`.
#     如果为 `true`，则在裁剪器上显示裁剪指南。默认为 `true`。
# *   `hideBottomControls`: If `true`, hides the bottom controls (crop, rotate, etc.) in the cropper. Defaults to `false`.
#     如果为 `true`，则在裁剪器中隐藏底部控件（裁剪、旋转等）。默认为 `false`。
# *   `enableRotation`: If `true`, allows rotation of the image in the cropper. Defaults to `false`.
#     如果为 `true`，则允许在裁剪器中旋转图片。默认为 `false`。
# *   `compressImageUtil`: Specifies the image compression utility to use. Can be `'native'` (default) or `'ios'` (for iOS only).
#     指定要使用的图片压缩工具。可以是 `'native'`（默认）或 `'ios'`（仅限 iOS）。
# *   `smartReframe`: If `true`, enables smart reframing for cropping. Defaults to `false`.
#     如果为 `true`，则启用智能重构以进行裁剪。默认为 `false`。
# *   `forceJpg`: If `true`, forces the output image to be in JPEG format. Defaults to `false`.
#     如果为 `true`，则强制输出图片为 JPEG 格式。默认为 `false`。
# *   `compressImageIo`: If `true`, compresses the image using the `image-compressor` library. Defaults to `false`.
#     如果为 `true`，则使用 `image-compressor` 库压缩图片。默认为 `false`。
# *   `minCompressResolution`: The minimum resolution for image compression. Defaults to `{ width: 100, height: 100 }`.
#     图片压缩的最小分辨率。默认为 `{ width: 100, height: 100 }`。
# *   `useFrontCamera`: If `true`, uses the front camera by default when opening the camera. Defaults to `false`.
#     如果为 `true`，则打开相机时默认使用前置摄像头。默认为 `false`。
# *   `compressVideos`: If `true`, compresses videos. Defaults to `true`.
#     如果为 `true`，则压缩视频。默认为 `true`。
# *   `videoExportPreset`: Specifies the video export preset. Defaults to `'Passthrough'`.
#     指定视频导出预设。默认为 `'Passthrough'`。
# *   `allowAssetSelectionFromPhotoLibrary`: If `true`, allows asset selection from the photo library. Defaults to `false`.
#     如果为 `true`，则允许从照片库中选择资源。默认为 `false`。
#
# ### `openCamera`
#
# This method opens the device's camera to take a photo or record a video.
#
# 此方法打开设备的相机以拍摄照片或录制视频。
#
# **Options:**
#
# 选项：
#
# The options for `openCamera` are similar to `openPicker`, with the addition of:
#
# `openCamera` 的选项与 `openPicker` 类似，并增加了以下选项：
#
# *   `useFrontCamera`: A boolean value to specify whether to use the front camera. Defaults to `false`.
#     一个布尔值，用于指定是否使用前置摄像头。默认为 `false`。
# *   `cameraDirection`: Specifies the camera direction. Can be `'back'` (default) or `'front'`.
#     指定相机方向。可以是 `'back'`（默认）或 `'front'`。
# *   `mute`: A boolean value to mute the camera sounds. Defaults to `false`.
#     一个布尔值，用于静音相机声音。默认为 `false`。
# *   `disableFlashIcon`: If `true`, disables the flash icon in the camera. Defaults to `false`.
#     如果为 `true`，则禁用相机中的闪光灯图标。默认为 `false`。
# *   `disableTorch`: If `true`, disables the torch in the camera. Defaults to `false`.
#     如果为 `true`，则禁用相机中的手电筒。默认为 `false`。
# *   `saveToPhotos`: A boolean value to save the captured photo/video to the device's gallery. Defaults to `true`.
#     一个布尔值，用于将捕获的照片/视频保存到设备的图库。默认为 `true`。
# *   `rotateEnabled`: A boolean value to enable/disable rotation for videos. Defaults to `true`.
#     一个布尔值，用于启用/禁用视频的旋转。默认为 `true`。
# *   `writeTempFile`: A boolean value to write the captured media to a temporary file. Defaults to `true`.
#     一个布尔值，用于将捕获的媒体写入临时文件。默认为 `true`。
# *   `enableRecording`: A boolean value to enable video recording. Defaults to `true`.
#     一个布尔值，用于启用视频录制。默认为 `true`。
# *   `captureMode`: Specifies the capture mode. Can be `'video'` or `'photo'`. Defaults to `'photo'`.
#     指定捕获模式。可以是 `'video'` 或 `'photo'`。默认为 `'photo'`。
# *   `maxDuration`: The maximum duration for video recording in seconds. Defaults to `0` (unlimited).
#     视频录制的最高时长（秒）。默认为 `0`（无限制）。
# *   `fps`: The frames per second for video recording. Defaults to `30`.
#     视频录制的每秒帧数。默认为 `30`。
# *   `videoBitrate`: The video bitrate for video recording. Defaults to `'2000k'`.
#     视频录制的视频比特率。默认为 `'2000k'`。
# *   `videoCodec`: The video codec for video recording. Defaults to `'h264'`.
#     视频录制的视频编解码器。默认为 `'h264'`。
# *   `videoExportPreset`: Specifies the video export preset. Defaults to `'Passthrough'`.
#     指定视频导出预设。默认为 `'Passthrough'`。
# *   `disableDeviceOrientation`: If `true`, disables device orientation changes in the camera. Defaults to `false`.
#     如果为 `true`，则禁用相机中的设备方向更改。默认为 `false`。
# *   `lockCaptureOrientation`: Specifies the orientation to lock the capture to. Can be `'all'`, `'portrait'`, or `'landscape'`. Defaults to `'all'`.
#     指定锁定捕获的方向。可以是 `'all'`、`'portrait'` 或 `'landscape'`。默认为 `'all'`。
# *   `allowAssetSelectionFromPhotoLibrary`: If `true`, allows asset selection from the photo library. Defaults to `false`.
#     如果为 `true`，则允许从照片库中选择资源。默认为 `false`。
#
# ### `clean()`
#
# This method cleans up temporary files created by the library. It's recommended to call this when the component unmounts.
#
# 此方法清理由库创建的临时文件。建议在组件卸载时调用此方法。
#
# ```jsx
# import React, { useEffect } from 'react';
# import { View, Button, Alert } from 'react-native';
# import ImagePicker from 'react-native-image-crop-picker';
#
# const App = () => {
#   useEffect(() => {
#     return () => {
#       ImagePicker.clean();
#     };
#   }, []);
#
#   const pickImage = () => {
#     ImagePicker.openPicker({
#       width: 300,
#       height: 400,
#       cropping: true,
#     })
#       .then((image) => {
#         console.log(image);
#       })
#       .catch((error) => {
#         console.log('ImagePicker Error: ', error);
#         Alert.alert('Error', 'Could not pick image.');
#       });
#   };
#
#   return (
#     <View style={{ flex: 1, justifyContent: 'center', alignItems: 'center' }}>
#       <Button title="Pick Image" onPress={pickImage} />
#     </View>
#   );
# };
#
# export default App;
# ```
#
# ### `cleanSingle`
#
# This method cleans a specific temporary file.
#
# 此方法清理特定的临时文件。
#
# ```jsx
# import React from 'react';
# import { View, Button, Image, Alert } from 'react-native';
# import ImagePicker from 'react-native-image-crop-picker';
#
# const App = () => {
#   const pickImageAndClean = () => {
#     ImagePicker.openPicker({
#       width: 300,
#       height: 400,
#       cropping: true,
#     })
#       .then((image) => {
#         console.log(image);
#         // Assuming image.path contains the path to the temporary file
#         ImagePicker.cleanSingle(image.path);
#       })
#       .catch((error) => {
#         console.log('ImagePicker Error: ', error);
#         Alert.alert('Error', 'Could not pick image.');
#       });
#   };
#
#   return (
#     <View style={{ flex: 1, justifyContent: 'center', alignItems: 'center' }}>
#       <Button title="Pick Image and Clean" onPress={pickImageAndClean} />
#     </View>
#   );
# };
#
# export default App;
# ```
#
# ### `ImagePickerResponse`
#
# The `ImagePickerResponse` object contains information about the picked or captured image/video.
#
# `ImagePickerResponse` 对象包含有关选择或捕获的图片/视频的信息。
#
# ```json
# {
#   "path": "file:///path/to/your/image.jpg", // Local path to the image/video
#   "mime": "image/jpeg", // MIME type of the image/video
#   "width": 1000, // Width of the image/video
#   "height": 800, // Height of the image/video
#   "data": "...", // Base64 encoded data if includeBase64 is true
#   "exif": { ... }, // EXIF data if includeExif is true
#   "cropRect": { // Cropping rectangle if cropping was enabled
#     "width": 300,
#     "height": 400,
#     "x": 50,
#     "y": 50
#   },
#   "size": 102400, // Size of the image/video in bytes
#   "filename": "image.jpg", // Filename of the image/video
#   "duration": 0, // Duration in seconds for videos, 0 for images
#   "sourceURL": "...", // Original URL of the image/video
#   "localIdentifier": "...", // Local identifier for the asset
#   "rotation": 0, // Rotation in degrees
#   "mediaType": "photo" // "photo" or "video"
# }
# ```
#
# ### `ImagePickerOptions`
#
# The `ImagePickerOptions` object allows you to configure the behavior of the image picker and camera.
#
# `ImagePickerOptions` 对象允许您配置图片选择器和相机的行为。
#
# Refer to the options listed under `openPicker` and `openCamera` for a comprehensive list of available configurations.
#
# 有关可用配置的完整列表，请参阅 `openPicker` 和 `openCamera` 下列出的选项。

# %%
from langchain.chat_models import init_chat_model

# Returns a langchain_openai.ChatOpenAI instance.
gpt_4o = init_chat_model("gpt-4o", model_provider="openai", temperature=0)
# Returns a langchain_anthropic.ChatAnthropic instance.
claude_opus = init_chat_model(
    "claude-3-opus-20240229", model_provider="anthropic", temperature=0
)
# Returns a langchain_google_vertexai.ChatVertexAI instance.
gemini_15 = init_chat_model(
    "gemini-1.5-pro", model_provider="google_vertexai", temperature=0
)

# Since all model integrations implement the ChatModel interface, you can use them in the same way.
print("GPT-4o: " + gpt_4o.invoke("what's your name").content + "\n")
print("Claude Opus: " + claude_opus.invoke("what's your name").content + "\n")
print("Gemini 1.5: " + gemini_15.invoke("what's your name").content + "\n")
# Out:
# /var/folders/4j/2rz3865x6qg07tx43146py8h0000gn/T/ipykernel_95293/571506279.py:4: LangChainBetaWarning: The function `init_chat_model` is in beta. It is actively being worked on, so the API may change.
#   gpt_4o = init_chat_model("gpt-4o", model_provider="openai", temperature=0)
# GPT-4o: I'm an AI created by OpenAI, and I don't have a personal name. How can I assist you today?
# Claude Opus: My name is Claude. It's nice to meet you!
# Gemini 1.5: I am a large language model, trained by Google.
#
# I don't have a name like a person does. You can call me Bard if you like! 😊

# %% [markdown]
# ## 推断模型提供商
#
# 对于常见且独特的模型名称，`init_chat_model()` 会尝试推断模型提供商。有关推断行为的完整列表，请参阅[API 参考](https://python.langchain.com/api_reference/langchain/chat_models/langchain.chat_models.base.init_chat_model.html)。例如，任何以 `gpt-3...` 或 `gpt-4...` 开头的模型都将被推断为使用 `openai` 模型提供商。

# %%
gpt_4o = init_chat_model("gpt-4o", temperature=0)
claude_opus = init_chat_model("claude-3-opus-20240229", temperature=0)
gemini_15 = init_chat_model("gemini-1.5-pro", temperature=0)

# %% [markdown]
# ## 创建可配置模型
#
# 您还可以通过指定 `configurable_fields` 来创建运行时可配置的模型。如果您不指定 `model` 值，那么“model”和“model_provider”将默认是可配置的。

# %%
configurable_model = init_chat_model(temperature=0)

configurable_model.invoke(
    "what's your name", config={"configurable": {"model": "gpt-4o"}}
)
# Out:
# AIMessage(content="I'm an AI created by OpenAI, and I don't have a personal name. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 11, 'total_tokens': 34}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_25624ae3a5', 'finish_reason': 'stop', 'logprobs': None}, id='run-b41df187-4627-490d-af3c-1c96282d3eb0-0', usage_metadata={'input_tokens': 11, 'output_tokens': 23, 'total_tokens': 34})

# %%
configurable_model.invoke(
    "what's your name", config={"configurable": {"model": "claude-3-5-sonnet-20240620"}}
)
# Out:
# AIMessage(content="My name is Claude. It's nice to meet you!", additional_kwargs={}, response_metadata={'id': 'msg_01Fx9P74A7syoFkwE73CdMMY', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 11, 'output_tokens': 15}}, id='run-a0fd2bbd-3b7e-46bf-8d69-a48c7e60b03c-0', usage_metadata={'input_tokens': 11, 'output_tokens': 15, 'total_tokens': 26})

# %% [markdown]
# ### 可配置模型及默认值
#
# 我们可以创建一个带有默认模型值的可配置模型，指定哪些参数是可配置的，并为可配置参数添加前缀：

# %%
first_llm = init_chat_model(
    model="gpt-4o",
    temperature=0,
    configurable_fields=("model", "model_provider", "temperature", "max_tokens"),
    config_prefix="first",  # useful when you have a chain with multiple models
)

first_llm.invoke("what's your name")
# Out:
# AIMessage(content="I'm an AI created by OpenAI, and I don't have a personal name. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 11, 'total_tokens': 34}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_25624ae3a5', 'finish_reason': 'stop', 'logprobs': None}, id='run-3380f977-4b89-4f44-bc02-b64043b3166f-0', usage_metadata={'input_tokens': 11, 'output_tokens': 23, 'total_tokens': 34})

# %%
first_llm.invoke(
    "what's your name",
    config={
        "configurable": {
            "first_model": "claude-3-5-sonnet-20240620",
            "first_temperature": 0.5,
            "first_max_tokens": 100,
        }
    },
)
# Out:
# AIMessage(content="My name is Claude. It's nice to meet you!", additional_kwargs={}, response_metadata={'id': 'msg_01EFKSWpmsn2PSYPQa4cNHWb', 'model': 'claude-3-5-sonnet-20240620', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 11, 'output_tokens': 15}}, id='run-3c58f47c-41b9-4e56-92e7-fb9602e3787c-0', usage_metadata={'input_tokens': 11, 'output_tokens': 15, 'total_tokens': 26})

# %% [markdown]
# ### 使用可配置模型进行声明式调用
#
# 我们可以像调用常规实例化聊天模型对象一样，在可配置模型上调用声明式操作，例如 `bind_tools`、`with_structured_output`、`with_configurable` 等，并以相同的方式链接可配置模型。

# %%
from pydantic import BaseModel, Field


class GetWeather(BaseModel):
    """Get the current weather in a given location"""

    location: str = Field(..., description="The city and state, e.g. San Francisco, CA")


class GetPopulation(BaseModel):
    """Get the current population in a given location"""

    location: str = Field(..., description="The city and state, e.g. San Francisco, CA")


llm = init_chat_model(temperature=0)
llm_with_tools = llm.bind_tools([GetWeather, GetPopulation])

llm_with_tools.invoke(
    "what's bigger in 2024 LA or NYC", config={"configurable": {"model": "gpt-4o"}}
).tool_calls
# Out:
# [{'name': 'GetPopulation',
#   'args': {'location': 'Los Angeles, CA'},
#   'id': 'call_Ga9m8FAArIyEjItHmztPYA22',
#   'type': 'tool_call'},
#  {'name': 'GetPopulation',
#   'args': {'location': 'New York, NY'},
#   'id': 'call_jh2dEvBaAHRaw5JUDthOs7rt',
#   'type': 'tool_call'}]

# %%
llm_with_tools.invoke(
    "what's bigger in 2024 LA or NYC",
    config={"configurable": {"model": "claude-3-5-sonnet-20240620"}},
).tool_calls
# Out:
# [{'name': 'GetPopulation',
#   'args': {'location': 'Los Angeles, CA'},
#   'id': 'toolu_01JMufPf4F4t2zLj7miFeqXp',
#   'type': 'tool_call'},
#  {'name': 'GetPopulation',
#   'args': {'location': 'New York City, NY'},
#   'id': 'toolu_01RQBHcE8kEEbYTuuS8WqY1u',
#   'type': 'tool_call'}]
