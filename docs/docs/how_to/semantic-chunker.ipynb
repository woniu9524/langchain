# %% [markdown]
# # 如何基于语义相似度分割文本
#
# 摘自 Greg Kamradt 的精彩笔记本：
# [5_Levels_Of_Text_Splitting](https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/5_Levels_Of_Text_Splitting.ipynb)
#
# 所有功劳归于他。
#
# 本指南涵盖了如何根据语义相似度分割文本块。如果嵌入向量的距离足够远，则会进行分割。
#
# 总体而言，这会将文本分割成句子，然后将句子分组为每组 3 个，最后合并嵌入空间中相似的文本块。

# %% [markdown]
# ## 安装依赖项

# %%
# !pip install --quiet langchain_experimental langchain_openai

# %% [markdown]
# ## 加载示例数据

# %%
# This is a long document we can split up.
with open("state_of_the_union.txt") as f:
    state_of_the_union = f.read()

# %% [markdown]
# ## 创建文本分词器
#
# A text splitter is a tool that breaks down a text into smaller pieces. This is useful for various natural language processing (NLP) tasks, such as:
#
# - **Information Retrieval:** Breaking down large documents into smaller chunks makes it easier to search and retrieve relevant information.
# - **Question Answering:** Splitting text into manageable segments allows models to process and understand context more effectively when answering questions.
# - **Summarization:** Text splitters can help in identifying key sentences or paragraphs for creating concise summaries.
# - **Language Modeling:** Smaller text segments can be used for training language models, improving their ability to learn patterns and relationships in language.
#
# There are several ways to split text, depending on the desired granularity and the nature of the text itself. Some common methods include:
#
# - **Sentence Splitting:** Dividing text into individual sentences. This is often done by identifying sentence-ending punctuation marks like periods (.), question marks (?), and exclamation points (!).
# - **Paragraph Splitting:** Breaking down text into paragraphs, typically separated by newline characters or double newline characters.
# - **Tokenization:** Further dividing sentences or paragraphs into smaller units called tokens, which can be words, sub-words, or even characters. This is a fundamental step in many NLP pipelines.
# - **Recursive Character Text Splitting:** A more advanced method that splits text recursively based on a list of separator characters. It tries to split on the first separator, and if the resulting chunks are still too large, it splits them again on the next separator, and so on. This method is particularly useful for handling complex documents with varying structures.
#
# In the context of large language models (LLMs), text splitters are crucial for managing the input context window. LLMs have a limit on the amount of text they can process at once. Text splitters help break down long documents into chunks that fit within this limit, ensuring that the model can effectively process and understand the information.
#
# ---
#
# 文本分词器是一种将文本分解成更小片段的工具。这对于各种自然语言处理 (NLP) 任务非常有用，例如：
#
# - **信息检索：** 将大型文档分解成更小的块，可以更轻松地搜索和检索相关信息。
# - **问答：** 将文本分割成可管理的片段，使模型在回答问题时能够更有效地处理和理解上下文。
# - **摘要：** 文本分词器可以帮助识别关键句子或段落，以创建简洁的摘要。
# - **语言建模：** 可以使用较小的文本片段来训练语言模型，提高它们学习语言模式和关系的能力。
#
# 根据所需的粒度和文本本身的性质，有几种方法可以分割文本。一些常见的方法包括：
#
# - **句子分割：** 将文本分割成单个句子。这通常通过识别句末标点符号（如句号（.）、问号（?）和感叹号（!））来完成。
# - **段落分割：** 将文本分割成段落，通常由换行符或双换行符分隔。
# - **分词：** 将句子或段落进一步分割成称为词元的更小单元，词元可以是单词、子词甚至字符。这是许多 NLP 管道中的基本步骤。
# - **递归字符文本分割：** 一种更高级的方法，它基于分隔符字符列表递归地分割文本。它尝试在第一个分隔符上进行分割，如果生成的块仍然太大，则在下一个分隔符上再次分割它们，依此类推。此方法对于处理具有不同结构的复杂文档特别有用。
#
# 在大型语言模型 (LLM) 的上下文中，文本分词器对于管理输入上下文窗口至关重要。LLM 对它们一次可以处理的文本量有限制。文本分词器有助于将长文档分解成适合此限制的块，确保模型能够有效地处理和理解信息。

# %% [markdown]
# 要实例化一个 [SemanticChunker](https://python.langchain.com/api_reference/experimental/text_splitter/langchain_experimental.text_splitter.SemanticChunker.html)，我们必须指定一个嵌入模型。下面我们将使用 [OpenAIEmbeddings](https://python.langchain.com/api_reference/community/embeddings/langchain_community.embeddings.openai.OpenAIEmbeddings.html)。

# %%
from langchain_experimental.text_splitter import SemanticChunker
from langchain_openai.embeddings import OpenAIEmbeddings

text_splitter = SemanticChunker(OpenAIEmbeddings())

# %% [markdown]
# ## 分割文本
#
# 我们以通常的方式分割文本，例如，通过调用 `.create_documents` 来创建 LangChain [Document](https://python.langchain.com/api_reference/core/documents/langchain_core.documents.base.Document.html) 对象：

# %%
docs = text_splitter.create_documents([state_of_the_union])
print(docs[0].page_content)
# Out:
# Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans. Last year COVID-19 kept us apart. This year we are finally together again. Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. With a duty to one another to the American people to the Constitution. And with an unwavering resolve that freedom will always triumph over tyranny. Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. He met the Ukrainian people. From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. Groups of citizens blocking tanks with their bodies. Everyone from students
# ...

# %% [markdown]
# ## 断点
#
# 此分块器通过确定何时“分割”句子来工作。这是通过查找任意两个句子之间的嵌入差异来实现的。当该差异超过某个阈值时，就会进行分割。
#
# 有几种方法可以确定该阈值，这些方法由 `breakpoint_threshold_type` 关键字参数控制。
#
# 注意：如果生成的分块大小过小/过大，可以使用额外的关键字参数 `breakpoint_threshold_amount` 和 `min_chunk_size` 进行调整。
#
# ### 百分位数
#
# 默认的分割方式是基于百分位数的。在此方法中，计算所有句子之间的差异，然后分割任何大于 X 百分位数的差异。X 的默认值为 95.0，可以通过关键字参数 `breakpoint_threshold_amount` 进行调整，该参数期望一个介于 0.0 和 100.0 之间的数字。

# %%
text_splitter = SemanticChunker(
    OpenAIEmbeddings(), breakpoint_threshold_type="percentile"
)

# %%
docs = text_splitter.create_documents([state_of_the_union])
print(docs[0].page_content)
# Out:
# Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans. Last year COVID-19 kept us apart. This year we are finally together again. Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. With a duty to one another to the American people to the Constitution. And with an unwavering resolve that freedom will always triumph over tyranny. Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. He met the Ukrainian people. From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. Groups of citizens blocking tanks with their bodies. Everyone from students
# ...

# %%
print(len(docs))
# Out:
# 26

# %% [markdown]
# ### 标准差
#
# 在此方法中，任何大于 X 个标准差的差异都会被拆分。X 的默认值为 3.0，可以通过关键字参数 `breakpoint_threshold_amount` 进行调整。

# %%
text_splitter = SemanticChunker(
    OpenAIEmbeddings(), breakpoint_threshold_type="standard_deviation"
)

# %%
docs = text_splitter.create_documents([state_of_the_union])
print(docs[0].page_content)
# Out:
# Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans. Last year COVID-19 kept us apart. This year we are finally together again. Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. With a duty to one another to the American people to the Constitution. And with an unwavering resolve that freedom will always triumph over tyranny. Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. He met the Ukrainian people. From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. Groups of citizens blocking tanks with their bodies. Everyone from students
# ...

# %%
print(len(docs))
# Out:
# 4

# %% [markdown]
# ### 四分位距
#
# 在此方法中，使用四分位距来分割块。四分位距可以通过关键字参数 `breakpoint_threshold_amount` 进行缩放，默认值为 1.5。

# %%
text_splitter = SemanticChunker(
    OpenAIEmbeddings(), breakpoint_threshold_type="interquartile"
)

# %%
docs = text_splitter.create_documents([state_of_the_union])
print(docs[0].page_content)
# Out:
# Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans. Last year COVID-19 kept us apart. This year we are finally together again. Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. With a duty to one another to the American people to the Constitution. And with an unwavering resolve that freedom will always triumph over tyranny. Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. He met the Ukrainian people. From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. Groups of citizens blocking tanks with their bodies. Everyone from students
# ...

# %%
print(len(docs))
# Out:
# 25

# %% [markdown]
# ### 梯度
#
# 在此方法中，距离的梯度与百分位法一起用于分割块。当块之间高度相关或特定于某个领域（例如法律或医疗）时，此方法非常有用。其思想是对梯度数组应用异常检测，从而使分布变宽，并易于识别高度语义化数据中的边界。
# 与百分位法类似，可以通过关键字参数 `breakpoint_threshold_amount` 调整分割，该参数期望一个介于 0.0 和 100.0 之间的数字，默认值为 95.0。

# %%
text_splitter = SemanticChunker(
    OpenAIEmbeddings(), breakpoint_threshold_type="gradient"
)

# %%
docs = text_splitter.create_documents([state_of_the_union])
print(docs[0].page_content)
# Out:
# Madam Speaker, Madam Vice President, our First Lady and Second Gentleman.

# %%
print(len(docs))
# Out:
# 26
