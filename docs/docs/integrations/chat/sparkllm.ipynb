# %% [markdown]
# # SparkLLM 聊天
#
# iFlyTek 的 SparkLLM 聊天模型 API。更多信息，请参阅 [iFlyTek 开放平台](https://www.xfyun.cn/)。

# %% [markdown]
# ## 基本用法
#
# This guide covers the basic usage of the `react-native-web` package.
# 本指南涵盖了 `react-native-web` 包的基本用法。
#
# `react-native-web` allows you to create React Native applications for the web.
# `react-native-web` 允许您为 Web 创建 React Native 应用程序。
#
# ### Installation
# ### 安装
#
# ```bash
# npm install --save react-native-web react-dom react
# # or
# yarn add react-native-web react-dom react
# ```
#
# ### Basic Example
# ### 基本示例
#
# ```jsx
# import React from 'react';
# import { Text, View } from 'react-native';
#
# const App = () => (
#   <View>
#     <Text>Hello, Web!</Text>
#   </View>
# );
#
# export default App;
# ```
#
# ### Webpack Configuration
# ### Webpack 配置
#
# To use `react-native-web` with Webpack, you need to configure it to resolve `react-native` imports to `react-native-web`.
# 要将 `react-native-web` 与 Webpack 一起使用，您需要配置它以将 `react-native` 导入解析到 `react-native-web`。
#
# Here's a basic `webpack.config.js` example:
# 这是一个基本的 `webpack.config.js` 示例：
#
# ```javascript
# const path = require('path');
#
# module.exports = {
#   // ... other webpack configurations
#   resolve: {
#     alias: {
#       'react-native$': 'react-native-web',
#     },
#     extensions: ['.web.js', '.js', '.jsx', '.json'],
#   },
#   module: {
#     rules: [
#       {
#         test: /\.js$/,
#         exclude: /node_modules/,
#         use: {
#           loader: 'babel-loader',
#           options: {
#             presets: ['module:metro-react-native-babel-preset'],
#           },
#         },
#       },
#       // ... other rules for assets like images, fonts, etc.
#     ],
#   },
# };
# ```
#
# ### Running the Application
# ### 运行应用程序
#
# Once you have configured Webpack, you can run your application using a development server:
# 配置好 Webpack 后，您可以使用开发服务器运行应用程序：
#
# ```bash
# webpack serve
# ```
#
# This will typically start a server at `http://localhost:8080` where you can view your React Native web application.
# 这通常会在 `http://localhost:8080` 启动一个服务器，您可以在其中查看您的 React Native Web 应用程序。

# %%
"""For basic init and call"""
from langchain_community.chat_models import ChatSparkLLM
from langchain_core.messages import HumanMessage

chat = ChatSparkLLM(
    spark_app_id="<app_id>", spark_api_key="<api_key>", spark_api_secret="<api_secret>"
)
message = HumanMessage(content="Hello")
chat([message])
# Out:
# AIMessage(content='Hello! How can I help you today?')

# %% [markdown]
# - 从 [iFlyTek SparkLLM API 控制台](https://console.xfyun.cn/services/bm3) 获取 SparkLLM 的 `app_id`、`api_key` 和 `api_secret`（更多信息请参阅 [iFlyTek SparkLLM 简介](https://xinghuo.xfyun.cn/sparkapi)），然后设置环境变量 `IFLYTEK_SPARK_APP_ID`、`IFLYTEK_SPARK_API_KEY` 和 `IFLYTEK_SPARK_API_SECRET`，或者在创建 `ChatSparkLLM` 时传递参数，如上面的演示所示。

# %% [markdown]
# ## ChatSparkLLM（流式输出）

# %%
chat = ChatSparkLLM(
    spark_app_id="<app_id>",
    spark_api_key="<api_key>",
    spark_api_secret="<api_secret>",
    streaming=True,
)
for chunk in chat.stream("Hello!"):
    print(chunk.content, end="")
# Out:
# Hello! How can I help you today?

# %% [markdown]
# ## v2 版本

# %%
"""For basic init and call"""
from langchain_community.chat_models import ChatSparkLLM
from langchain_core.messages import HumanMessage

chat = ChatSparkLLM(
    spark_app_id="<app_id>",
    spark_api_key="<api_key>",
    spark_api_secret="<api_secret>",
    spark_api_url="wss://spark-api.xf-yun.com/v2.1/chat",
    spark_llm_domain="generalv2",
)
message = HumanMessage(content="Hello")
chat([message])
