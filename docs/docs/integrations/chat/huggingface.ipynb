# %% [markdown]
# # ChatHuggingFace
#
# 这将帮助您开始使用 `langchain_huggingface` [聊天模型](/docs/concepts/chat_models)。有关 `ChatHuggingFace` 所有功能和配置的详细文档，请访问 [API 参考](https://python.langchain.com/api_reference/huggingface/chat_models/langchain_huggingface.chat_models.huggingface.ChatHuggingFace.html)。有关 Hugging Face 支持的模型列表，请查看 [此页面](https://huggingface.co/models)。
#
# ## 概述
# ### 集成详情
#
# ### 集成详情
#
# | 类 | 包 | 本地 | 可序列化 | JS 支持 | 包下载 | 包最新版本 |
# | :--- | :--- | :---: | :---: |  :---: | :---: | :---: |
# | [ChatHuggingFace](https://python.langchain.com/api_reference/huggingface/chat_models/langchain_huggingface.chat_models.huggingface.ChatHuggingFace.html) | [langchain-huggingface](https://python.langchain.com/api_reference/huggingface/index.html) | ✅ | beta | ❌ | ![PyPI - Downloads](https://img.shields.io/pypi/dm/langchain_huggingface?style=flat-square&label=%20) | ![PyPI - Version](https://img.shields.io/pypi/v/langchain_huggingface?style=flat-square&label=%20) |
#
# ### 模型特性
# | [工具调用](/docs/how_to/tool_calling) | [结构化输出](/docs/how_to/structured_output/) | JSON 模式 | [图像输入](/docs/how_to/multimodal_inputs/) | 音频输入 | 视频输入 | [Token 级流式传输](/docs/how_to/chat_streaming/) | 原生异步 | [Token 使用量](/docs/how_to/chat_token_usage_tracking/) | [Logprobs](/docs/how_to/logprobs/) |
# | :---: | :---: | :---: | :---: |  :---: | :---: | :---: | :---: | :---: | :---: |
# | ✅ | ✅ | ❌ | ✅ | ✅ | ✅ | ❌ | ✅ | ✅ | ❌ |
#
# ## 设置
#
# 要访问 Hugging Face 模型，您需要创建一个 Hugging Face 账户，获取 API 密钥，并安装 `langchain-huggingface` 集成包。
#
# ### 凭证
#
# 生成一个 [Hugging Face 访问令牌](https://huggingface.co/docs/hub/security-tokens)，并将其存储为环境变量：`HUGGINGFACEHUB_API_TOKEN`。

# %%
import getpass
import os

if not os.getenv("HUGGINGFACEHUB_API_TOKEN"):
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = getpass.getpass("Enter your token: ")

# %% [markdown]
# ### 安装
#
# | 类 | 包 | 本地 | 可序列化 | JS 支持 | 包下载量 | 包最新版本 |
# | :--- | :--- | :---: | :---: |  :---: | :---: | :---: |
# | [ChatHuggingFace](https://python.langchain.com/api_reference/huggingface/chat_models/langchain_huggingface.chat_models.huggingface.ChatHuggingFace.html) | [langchain_huggingface](https://python.langchain.com/api_reference/huggingface/index.html) | ✅ | ❌ | ❌ | ![PyPI - Downloads](https://img.shields.io/pypi/dm/langchain_huggingface?style=flat-square&label=%20) | ![PyPI - Version](https://img.shields.io/pypi/v/langchain_huggingface?style=flat-square&label=%20) |
#
# ### 模型特性
# | [工具调用](/docs/how_to/tool_calling) | [结构化输出](/docs/how_to/structured_output/) | JSON 模式 | [图像输入](/docs/how_to/multimodal_inputs/) | 音频输入 | 视频输入 | [Token 流式输出](/docs/how_to/chat_streaming/) | 原生异步 | [Token 使用量跟踪](/docs/how_to/chat_token_usage_tracking/) | [Logprobs](/docs/how_to/logprobs/) |
# | :---: | :---: | :---: | :---: |  :---: | :---: | :---: | :---: | :---: | :---: |
# | ✅ | ✅ | ❌ | ❌ | ❌ | ❌ | ❌ | ❌ | ❌ | ❌ |
#
# ## 设置
#
# 要访问 `langchain_huggingface` 模型，您需要创建一个 `Hugging Face` 账户，获取 API 密钥，并安装 `langchain_huggingface` 集成包。
#
# ### 凭证
#
# 您需要将 [Hugging Face 访问令牌](https://huggingface.co/docs/hub/security-tokens) 保存为环境变量：`HUGGINGFACEHUB_API_TOKEN`。

# %%
import getpass
import os

os.environ["HUGGINGFACEHUB_API_TOKEN"] = getpass.getpass(
    "Enter your Hugging Face API key: "
)

# %%
# %pip install --upgrade --quiet  langchain-huggingface text-generation transformers google-search-results numexpr langchainhub sentencepiece jinja2 bitsandbytes accelerate
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 实例化
#
# 您可以通过两种方式实例化 `ChatHuggingFace` 模型：从 `HuggingFaceEndpoint` 实例化，或从 `HuggingFacePipeline` 实例化。

# %% [markdown]
# ### `HuggingFaceEndpoint`

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    task="text-generation",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
)

chat_model = ChatHuggingFace(llm=llm)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /Users/isaachershenson/.cache/huggingface/token
# Login successful

# %% [markdown]
# 现在，让我们利用 [推理提供商](https://huggingface.co/docs/inference-providers) 在特定的第三方提供商上运行模型

# %%
llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    task="text-generation",
    provider="hyperbolic",  # set your provider here
    # provider="nebius",
    # provider="together",
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# ### `HuggingFacePipeline`
#
# `HuggingFacePipeline` 是一个用于在 Hugging Face Transformers 库中创建和管理管道的类。管道是一种方便的方式，可以轻松地将预训练模型用于各种 NLP 任务，例如文本分类、命名实体识别、问答等。
#
# **主要特点：**
#
# *   **易于使用：** `HuggingFacePipeline` 提供了一个简单的接口来加载和使用预训练模型，无需深入了解模型的底层细节。
# *   **任务支持：** 支持 Hugging Face Transformers 库中的多种 NLP 任务。
# *   **灵活性：** 允许用户自定义模型、分词器和管道参数。
# *   **集成：** 可以与其他库和框架（如 LangChain）无缝集成。
#
# **安装：**
#
# 您可以使用 pip 安装 `transformers` 库：
#
# ```bash
# pip install transformers
# ```
#
# **基本用法：**
#
# 以下是如何使用 `HuggingFacePipeline` 执行文本分类任务的示例：
#
# ```python
# from transformers import pipeline
#
# # 创建一个文本分类管道
# classifier = pipeline("sentiment-analysis")
#
# # 使用管道进行预测
# result = classifier("This is a great movie!")
# print(result)
# ```
#
# **使用 `HuggingFacePipeline` 类：**
#
# 您也可以直接实例化 `HuggingFacePipeline` 类来创建管道：
#
# ```python
# from transformers import AutoModelForSequenceClassification, AutoTokenizer
# from transformers.pipelines import Pipeline
#
# # 加载预训练模型和分词器
# model_name = "distilbert-base-uncased-finetuned-sst-2-english"
# model = AutoModelForSequenceClassification.from_pretrained(model_name)
# tokenizer = AutoTokenizer.from_pretrained(model_name)
#
# # 创建 HuggingFacePipeline 实例
# hf_pipeline = Pipeline(
#     task="sentiment-analysis",
#     model=model,
#     tokenizer=tokenizer,
#     device=0 # 使用 GPU，如果可用
# )
#
# # 使用管道进行预测
# result = hf_pipeline("This is a fantastic library!")
# print(result)
# ```
#
# **参数：**
#
# `HuggingFacePipeline` 类的构造函数接受以下主要参数：
#
# *   `task` (str): 要执行的 NLP 任务的名称（例如，`"sentiment-analysis"`、`"zero-shot-classification"`、`"text-generation"`）。
# *   `model` (str 或 Model): 要使用的模型。可以是模型的名称（例如，`"bert-base-uncased"`）或已加载的模型实例。
# *   `tokenizer` (str 或 Tokenizer): 要使用的分词器。可以是分词器的名称或已加载的分词器实例。
# *   `framework` (str, 可选): 要使用的深度学习框架（`"pt"` 表示 PyTorch，`"tf"` 表示 TensorFlow）。如果未指定，则会自动检测。
# *   `device` (int, 可选): 要在哪个设备上运行模型（例如，`0` 表示第一个 GPU，`-1` 表示 CPU）。
# *   `return_all_scores` (bool, 可选): 对于某些任务，是否返回所有类别的分数。
# *   `config` (dict, 可选): 用于配置管道的额外参数。
#
# **高级用法：**
#
# *   **自定义模型和分词器：** 您可以加载本地保存的模型和分词器，或使用 Hugging Face Hub 上的任何模型。
# *   **指定任务特定参数：** 许多任务允许您传递特定的参数来控制模型的行为，例如 `max_length`、`num_beams` 等。
#
# ```python
# from transformers import pipeline
#
# # 使用文本生成管道，并指定 max_length
# generator = pipeline("text-generation", model="gpt2")
# result = generator("Once upon a time", max_length=50, num_return_sequences=2)
# print(result)
# ```
#
# **总结：**
#
# `HuggingFacePipeline` 是一个强大的工具，可以简化在 Hugging Face Transformers 中使用预训练模型的过程。它提供了对各种 NLP 任务的便捷访问，并允许用户根据自己的需求进行自定义。

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline

llm = HuggingFacePipeline.from_model_id(
    model_id="HuggingFaceH4/zephyr-7b-beta",
    task="text-generation",
    pipeline_kwargs=dict(
        max_new_tokens=512,
        do_sample=False,
        repetition_penalty=1.03,
    ),
)

chat_model = ChatHuggingFace(llm=llm)
# Out:
# config.json:   0%|          | 0.00/638 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00008.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00002-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00003-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00004-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00005-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/816M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %% [markdown]
# ### 使用量化实例化
#
# 要运行模型的量化版本，您可以按如下方式指定 `bitsandbytes` 量化配置：

# %%
from transformers import BitsAndBytesConfig

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="float16",
    bnb_4bit_use_double_quant=True,
)

# %% [markdown]
# 并将其作为 `model_kwargs` 的一部分传递给 `HuggingFacePipeline`：

# %%
llm = HuggingFacePipeline.from_model_id(
    model_id="HuggingFaceH4/zephyr-7b-beta",
    task="text-generation",
    pipeline_kwargs=dict(
        max_new_tokens=512,
        do_sample=False,
        repetition_penalty=1.03,
        return_full_text=False,
    ),
    model_kwargs={"quantization_config": quantization_config},
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# ## 调用

# %%
from langchain_core.messages import (
    HumanMessage,
    SystemMessage,
)

messages = [
    SystemMessage(content="You're a helpful assistant"),
    HumanMessage(
        content="What happens when an unstoppable force meets an immovable object?"
    ),
]

ai_msg = chat_model.invoke(messages)

# %%
print(ai_msg.content)
# Out:
# According to the popular phrase and hypothetical scenario, when an unstoppable force meets an immovable object, a paradoxical situation arises as both forces are seemingly contradictory. On one hand, an unstoppable force is an entity that cannot be stopped or prevented from moving forward, while on the other hand, an immovable object is something that cannot be moved or displaced from its position.
#
# In this scenario, it is un

# %% [markdown]
# ## API 参考
#
# 有关 `ChatHuggingFace` 所有功能和配置的详细文档，请访问 API 参考：https://python.langchain.com/api_reference/huggingface/chat_models/langchain_huggingface.chat_models.huggingface.ChatHuggingFace.html

# %% [markdown]
# ## API 参考
#
# 有关 ChatHuggingFace 所有功能和配置的详细文档，请访问 API 参考：https://python.langchain.com/api_reference/huggingface/chat_models/langchain_huggingface.chat_models.huggingface.ChatHuggingFace.html
