# %% [markdown]
# # Dappier AI

# %% [markdown]
# **Dappier：用动态、实时数据模型赋能 AI**
#
# Dappier 提供了一个尖端平台，让开发者能够即时访问涵盖新闻、娱乐、金融、市场数据、天气等领域的广泛实时数据模型。借助我们预训练的数据模型，您可以为您的 AI 应用程序注入强大动力，确保它们提供精确、最新的响应，并最大限度地减少不准确性。
#
# Dappier 数据模型帮助您构建下一代 LLM 应用，这些应用可信赖地获取来自世界领先品牌的最新内容。通过简单的 API，释放您的创造力，并利用可操作的专有数据增强任何 GPT 应用或 AI 工作流。用来自可信来源的专有数据来增强您的 AI，是确保事实准确、内容最新、减少幻觉的最佳方式，无论问题是什么。
#
# 为开发者而生，由开发者打造
# Dappier 的设计充分考虑了开发者的需求，简化了从数据集成到货币化的整个过程，提供了清晰、直接的路径来部署您的 AI 模型并从中获利。在 **https://dappier.com/** 体验新互联网货币化基础设施的未来。

# %% [markdown]
# 本示例将介绍如何使用 LangChain 与 Dappier AI 模型进行交互
#
# -----------------------------------------------------------------------------------

# %% [markdown]
# 要使用我们的 Dappier AI 数据模型，您需要一个 API 密钥。请访问 Dappier Platform (https://platform.dappier.com/) 登录并在您的个人资料中创建 API 密钥。
#
# 您可以在 API 参考中找到更多详细信息：https://docs.dappier.com/introduction

# %% [markdown]
# 要使用我们的 Dappier Chat Model，您可以在初始化类时通过名为 `dappier_api_key` 的参数直接传递密钥，或者将其设置为环境变量。
#
# ```bash
# export DAPPIER_API_KEY="..."

# %%
from langchain_community.chat_models.dappier import ChatDappierAI
from langchain_core.messages import HumanMessage

# %%
chat = ChatDappierAI(
    dappier_endpoint="https://api.dappier.com/app/datamodelconversation",
    dappier_model="dm_01hpsxyfm2fwdt2zet9cg6fdxt",
    dappier_api_key="...",
)

# %%
messages = [HumanMessage(content="Who won the super bowl in 2024?")]
chat.invoke(messages)
# Out:
# AIMessage(content='Hey there! The Kansas City Chiefs won Super Bowl LVIII in 2024. They beat the San Francisco 49ers in overtime with a final score of 25-22. It was quite the game! 🏈')

# %%
await chat.ainvoke(messages)
# Out:
# AIMessage(content='The Kansas City Chiefs won Super Bowl LVIII in 2024! 🏈')
