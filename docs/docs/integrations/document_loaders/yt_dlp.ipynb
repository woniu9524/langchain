# %% [raw]
# ---
# sidebar_label: YoutubeLoaderDL
# ---

# %% [markdown]
# # YoutubeLoaderDL
#
# 利用 `yt-dlp` 库加载 Youtube 内容的 Loader。
#
# 本包实现了 Youtube 的[文档加载器](/docs/concepts/document_loaders/)。与之不同的是 `langchain-community` 的 [YoutubeLoader](https://python.langchain.com/api_reference/community/document_loaders/langchain_community.document_loaders.youtube.YoutubeLoader.html)，后者依赖于 `pytube`，`YoutubeLoaderDL` 能够获取 YouTube 元数据。`langchain-yt-dlp` 利用强大的 `yt-dlp` 库，提供了一个更可靠、功能更丰富的 YouTube 文档加载器。
#
# ## 概览
# ### 集成细节
#
# | Class | Package | Local | Serializable | JS Support |
# | :--- | :--- | :---: | :---: | :---: |
# | YoutubeLoader | langchain-yt-dlp | ✅ | ✅ | ❌ |
#
# ## 设置
#
# ### 安装
#
# ```bash
# pip install langchain-yt-dlp
# ```

# %% [markdown]
# ### 初始化

# %%
from langchain_yt_dlp.youtube_loader import YoutubeLoaderDL

# Basic transcript loading
loader = YoutubeLoaderDL.from_youtube_url(
    "https://www.youtube.com/watch?v=dQw4w9WgXcQ", add_video_info=True
)

# %% [markdown]
# ### 加载

# %%
documents = loader.load()

# %%
documents[0].metadata
# Out:
# {'source': 'dQw4w9WgXcQ',
#  'title': 'Rick Astley - Never Gonna Give You Up (Official Music Video)',
# ...

# %% [markdown]
# ## 懒加载

# %% [markdown]
# - 未实现延迟加载

# %% [markdown]
# ## API 参考：
#
# - [Github](https://github.com/aqib0770/langchain-yt-dlp)
# - [PyPi](https://pypi.org/project/langchain-yt-dlp/)
