# %% [markdown]
# # TileDB
#
# > [TileDB](https://github.com/TileDB-Inc/TileDB) 是一个强大的引擎，用于索引和查询密集型及稀疏型多维数组。
#
# > TileDB 通过 [TileDB-Vector-Search](https://github.com/TileDB-Inc/TileDB-Vector-Search) 模块提供 ANN 搜索能力。它支持 ANN 查询的无服务器执行，并将向量索引存储在本地磁盘和云对象存储（例如 AWS S3）上。
#
# 更多详情请参见：
# -  [为什么选择 TileDB 作为向量数据库](https://tiledb.com/blog/why-tiledb-as-a-vector-database)
# -  [TileDB 101：向量搜索](https://tiledb.com/blog/tiledb-101-vector-search)
#
# 本 Notebook 展示了如何使用 `TileDB` 向量数据库。

# %%
# %pip install --upgrade --quiet  tiledb-vector-search langchain-community

# %% [markdown]
# ## 基本示例

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import TileDB
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_text_splitters import CharacterTextSplitter

raw_documents = TextLoader("../../how_to/state_of_the_union.txt").load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
documents = text_splitter.split_documents(raw_documents)
model_name = "sentence-transformers/all-mpnet-base-v2"
embeddings = HuggingFaceEmbeddings(model_name=model_name)
db = TileDB.from_documents(
    documents, embeddings, index_uri="/tmp/tiledb_index", index_type="FLAT"
)

# %%
query = "What did the president say about Ketanji Brown Jackson"
docs = db.similarity_search(query)
docs[0].page_content

# %% [markdown]
# ### 按向量进行相似性搜索
#
# Vector similarity search is a method for finding items that are similar to a given item. It is often used in applications such as recommendation systems, image retrieval, and natural language processing.
#
# 向量相似性搜索是一种查找与给定项相似的项的方法。它常用于推荐系统、图像检索和自然语言处理等应用。
#
# In this guide, you will learn how to perform vector similarity search using the following methods:
#
# 在本指南中，您将学习如何使用以下方法执行向量相似性搜索：
#
# *   **Approximate Nearest Neighbor (ANN) search**: This method uses a set of algorithms to find approximate nearest neighbors to a query vector. It is generally faster than exact nearest neighbor search, but may not always return the exact nearest neighbors.
#     *   **近似最近邻 (ANN) 搜索**：此方法使用一组算法来查找查询向量的近似最近邻。它通常比精确最近邻搜索更快，但可能并不总是返回精确的最近邻。
# *   **Exact Nearest Neighbor (ENN) search**: This method uses a set of algorithms to find the exact nearest neighbors to a query vector. It is generally slower than approximate nearest neighbor search, but guarantees to return the exact nearest neighbors.
#     *   **精确最近邻 (ENN) 搜索**：此方法使用一组算法来查找查询向量的精确最近邻。它通常比近似最近邻搜索慢，但保证返回精确的最近邻。
#
# The following sections will guide you through the process of performing vector similarity search using both ANN and ENN methods.
#
# 以下各节将指导您完成使用 ANN 和 ENN 方法执行向量相似性搜索的过程。

# %%
embedding_vector = embeddings.embed_query(query)
docs = db.similarity_search_by_vector(embedding_vector)
docs[0].page_content

# %% [markdown]
# ### 相似度搜索与评分
#
# When you perform a similarity search, you're essentially asking the system to find items that are most like a given item. This is often done by calculating a similarity score between the query item and all other items in the dataset. The higher the score, the more similar the items are considered to be.
#
# 在执行相似度搜索时，您实际上是在要求系统查找与给定项最相似的项。这通常通过计算查询项与数据集中所有其他项之间的相似度得分来完成。得分越高，则认为项越相似。
#
# Here's a breakdown of how similarity search with scoring typically works:
#
# 以下是带有评分的相似度搜索通常工作方式的细分：
#
# 1.  **Query Item:** You start with a specific item (the "query item") for which you want to find similar items. This could be a product, a document, an image, or any other data point.
#
#     1.  **查询项：** 您从一个特定的项（“查询项”）开始，您希望找到与之相似的项。这可以是一个产品、文档、图像或任何其他数据点。
#
# 2.  **Feature Extraction/Vectorization:** The system needs a way to represent each item numerically so that comparisons can be made. This often involves extracting key features or converting the item into a numerical vector (an embedding). For text, this might involve techniques like TF-IDF or word embeddings (Word2Vec, GloVe, FastText). For images, it might involve using pre-trained neural networks to extract feature vectors.
#
#     2.  **特征提取/向量化：** 系统需要一种方法来以数值方式表示每个项，以便进行比较。这通常涉及提取关键特征或将项转换为数值向量（嵌入）。对于文本，这可能涉及 TF-IDF 或词嵌入（Word2Vec、GloVe、FastText）等技术。对于图像，这可能涉及使用预训练的神经网络来提取特征向量。
#
# 3.  **Similarity Metric:** A mathematical formula is used to calculate the "distance" or "similarity" between two vectors. Common similarity metrics include:
#
#     3.  **相似度度量：** 使用数学公式来计算两个向量之间的“距离”或“相似度”。常见的相似度度量包括：
#     *   **Cosine Similarity:** Measures the cosine of the angle between two non-zero vectors. It's widely used for text data as it focuses on the orientation of vectors rather than their magnitude. A score of 1 means perfect similarity, 0 means no similarity, and -1 means perfect dissimilarity.
#
#         *   **余弦相似度：** 测量两个非零向量之间夹角的余弦值。它广泛用于文本数据，因为它关注向量的方向而不是其大小。得分为 1 表示完全相似，0 表示不相似，-1 表示完全不相似。
#     *   **Euclidean Distance:** Calculates the straight-line distance between two points in Euclidean space. Smaller distances indicate higher similarity.
#
#         *   **欧氏距离：** 计算欧几里得空间中两点之间的直线距离。距离越小表示相似度越高。
#     *   **Dot Product:** The dot product of two vectors. If the vectors are normalized, it's equivalent to cosine similarity.
#
#         *   **点积：** 两个向量的点积。如果向量已归一化，则等同于余弦相似度。
#     *   **Jaccard Similarity:** Used for comparing sets. It's the size of the intersection divided by the size of the union of the two sets.
#
#         *   **Jaccard相似度：** 用于比较集合。它是两个集合交集的大小除以并集的大小。
#
# 4.  **Scoring and Ranking:** The chosen similarity metric is applied to the query item's vector and the vectors of all other items in the dataset. This generates a similarity score for each item. The items are then ranked based on these scores, with the highest scores indicating the most similar items.
#
#     4.  **评分与排名：** 将所选的相似度度量应用于查询项的向量以及数据集中所有其他项的向量。这将为每个项生成一个相似度得分。然后根据这些得分对项进行排名，得分最高的项表示最相似的项。
#
# 5.  **Thresholding (Optional):** You might set a minimum similarity score threshold. Only items with a score above this threshold will be returned as results. This helps filter out items that are not sufficiently similar.
#
#     5.  **阈值设置（可选）：** 您可以设置一个最低相似度得分阈值。只有得分高于此阈值的项才会被作为结果返回。这有助于过滤掉不够相似的项。
#
# **Example Scenario:**
#
# **示例场景：**
#
# Imagine you have a collection of news articles, and you want to find articles similar to a specific article about "AI advancements."
#
# 假设您有一系列新闻文章，并且您想查找与一篇关于“人工智能进展”的特定文章相似的文章。
#
# 1.  **Query Article:** "The latest breakthroughs in artificial intelligence are revolutionizing industries..."
#     1.  **查询文章：** “人工智能的最新突破正在彻底改变各行各业……”
# 2.  **Vectorization:** Each article is converted into a numerical vector representing its content.
#     2.  **向量化：** 每篇文章都被转换为一个数值向量，代表其内容。
# 3.  **Similarity Metric:** Cosine similarity is chosen.
#     3.  **相似度度量：** 选择余弦相似度。
# 4.  **Scoring:** The system calculates the cosine similarity between the query article's vector and all other article vectors.
#     4.  **评分：** 系统计算查询文章向量与其他所有文章向量之间的余弦相似度。
#     *   Article A ("New AI applications in healthcare"): Score 0.85
#         *   A 文章（“人工智能在医疗保健中的新应用”）：得分 0.85
#     *   Article B ("Impact of machine learning on finance"): Score 0.72
#         *   B 文章（“机器学习对金融的影响”）：得分 0.72
#     *   Article C ("Advances in quantum computing"): Score 0.30
#         *   C 文章（“量子计算的进展”）：得分 0.30
#     *   Article D ("Ethical considerations of AI"): Score 0.88
#         *   D 文章（“人工智能的伦理考量”）：得分 0.88
# 5.  **Ranking:** The articles are ranked: Article D, Article A, Article B, Article C.
#     5.  **排名：** 文章排名为：D 文章、A 文章、B 文章、C 文章。
# 6.  **Thresholding (Optional):** If a threshold of 0.70 was set, all returned articles would be considered relevant.
#     6.  **阈值设置（可选）：** 如果设置了 0.70 的阈值，所有返回的文章都将被认为相关。
#
# This process allows systems to effectively surface relevant content based on semantic or feature-based similarity.
#
# 这个过程使系统能够根据语义或基于特征的相似度有效地展示相关内容。

# %%
docs_and_scores = db.similarity_search_with_score(query)
docs_and_scores[0]

# %% [markdown]
# ## 最大化边际相关性搜索 (MMR)

# %% [markdown]
# 除了在检索器对象中使用相似性搜索外，您还可以使用 `mmr` 作为检索器。

# %%
retriever = db.as_retriever(search_type="mmr")
retriever.invoke(query)

# %% [markdown]
# 或者直接使用 `max_marginal_relevance_search`：

# %%
db.max_marginal_relevance_search(query, k=2, fetch_k=10)
