# %% [markdown]
# # Atlas
#
#
# >[Atlas](https://docs.nomic.ai/index.html) 是 Nomic 公司推出的一个平台，用于与从小规模到互联网规模的非结构化数据集进行交互。它使用户能够在浏览器中可视化、搜索和共享海量数据集。
#
# 您需要安装 `langchain-community` 才能使用此集成，命令为 `pip install -qU langchain-community`
#
# 本笔记本将展示如何使用与 `AtlasDB` 向量存储相关的功能。

# %%
# %pip install --upgrade --quiet  spacy

# %%
# !python3 -m spacy download en_core_web_sm

# %%
# %pip install --upgrade --quiet  nomic

# %% [markdown]
# ### 加载包

# %%
import time

from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import AtlasDB
from langchain_text_splitters import SpacyTextSplitter

# %%
ATLAS_TEST_API_KEY = "7xDPkYXSYDc1_ErdTPIcoAR9RNd8YDlkS3nVNXcVoIMZ6"

# %% [markdown]
# ### 准备数据

# %%
loader = TextLoader("../../how_to/state_of_the_union.txt")
documents = loader.load()
text_splitter = SpacyTextSplitter(separator="|")
texts = []
for doc in text_splitter.split_documents(documents):
    texts.extend(doc.page_content.split("|"))

texts = [e.strip() for e in texts]

# %% [markdown]
# ### 使用 Nomic 的 Atlas 映射数据
#
# Atlas 是一个用于构建和探索大规模数据集的工具。它允许你将数据映射到高维空间，并以交互式的方式进行可视化和分析。
#
# **核心概念**
#
# *   **Embedding（嵌入）**: Atlas 的核心是将你的数据（例如文本、图像、音频等）转换为数字向量（嵌入）。这些嵌入捕获了数据的语义信息，使得相似的数据在向量空间中彼此靠近。
# *   **Dataset（数据集）**: Atlas 中的数据集是你的嵌入以及与之关联的元数据。你可以上传自己的数据，或者使用 Atlas 提供的预训练模型生成嵌入。
# *   **Explorer（探索器）**: Explorer 是 Atlas 的可视化界面，允许你以交互式的方式探索你的数据集。你可以缩放、平移、搜索和过滤数据，还可以查看单个数据点的详细信息。
#
# **如何使用 Atlas 映射数据**
#
# 1.  **准备你的数据**:
#     *   确保你的数据是结构化的，例如 CSV 文件、JSON 文件或数据库。
#     *   如果你的数据是文本，你需要将其转换为嵌入。你可以使用预训练的语言模型（如 Sentence-BERT）来生成文本嵌入。
#     *   如果你的数据是图像或音频，也有相应的模型可以生成嵌入。
#
# 2.  **创建 Atlas 数据集**:
#     *   访问 Nomic AI 的网站并创建一个账户。
#     *   在 Atlas 中，创建一个新的数据集。
#     *   上传你的数据。如果你的数据已经是嵌入格式，可以直接上传。否则，你需要使用 Atlas 提供的工具或外部库来生成嵌入并上传。
#
# 3.  **探索你的数据**:
#     *   一旦你的数据集被创建并处理完毕，你就可以在 Explorer 中打开它。
#     *   你可以使用鼠标滚轮进行缩放，拖动鼠标进行平移。
#     *   使用顶部的搜索栏来查找特定的数据点。
#     *   利用左侧的过滤器来筛选数据，例如按标签、按相似度等。
#     *   点击任何一个数据点，可以在右侧面板中查看其详细信息和元数据。
#
# **高级功能**
#
# *   **自定义可视化**: Atlas 允许你自定义数据的可视化方式，例如更改颜色、大小和形状。
# *   **聚类和降维**: 你可以使用 Atlas 内置的聚类算法或降维技术（如 t-SNE、UMAP）来进一步分析你的数据。
# *   **协作**: Atlas 支持团队协作，你可以与他人共享你的数据集和探索器。
# *   **API 集成**: Atlas 提供 API，允许你将 Atlas 集成到你自己的应用程序或工作流中。
#
# **示例**
#
# 假设你有一个包含 10,000 篇新闻文章的数据集。你可以使用 Sentence-BERT 将每篇文章转换为一个 768 维的向量嵌入。然后，将这些嵌入上传到 Atlas。在 Atlas Explorer 中，你可以看到这些文章在向量空间中的分布。你可以通过搜索关键词来查找相关文章，或者通过聚类来发现不同主题的新闻。
#
# Atlas 是一个强大而灵活的工具，可以帮助你理解和利用大规模数据集。通过将数据映射到可交互的可视化空间，你可以发现隐藏的模式、洞察和关联。

# %%
db = AtlasDB.from_texts(
    texts=texts,
    name="test_index_" + str(time.time()),  # unique name for your vector store
    description="test_index",  # a description for your vector store
    api_key=ATLAS_TEST_API_KEY,
    index_kwargs={"build_topic_model": True},
)

# %%
db.project.wait_for_project_lock()

# %%
db.project

# %% [markdown]
# 这是代码运行结果的地图。此地图展示了国情咨文的文本。
# https://atlas.nomic.ai/map/3e4de075-89ff-486a-845c-36c23f30bb67/d8ce2284-8edb-4050-8b9b-9bb543d7f647
