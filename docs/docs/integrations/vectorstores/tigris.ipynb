# %% [markdown]
# # Tigris
#
# > [Tigris](https://tigrisdata.com) 是一个开源的无服务器 NoSQL 数据库和搜索平台，旨在简化高性能向量搜索应用程序的构建。
# > `Tigris` 消除了管理、运行和同步多个工具的基础设施复杂性，让您可以专注于构建出色的应用程序。

# %% [markdown]
# 本笔记本将指导您如何将 Tigris 用作您的 VectorStore

# %% [markdown]
# **先决条件**
# 1. OpenAI 账户。您可以在[此处](https://platform.openai.com/)注册账户。
# 2. [注册一个免费的 Tigris 账户](https://console.preview.tigrisdata.cloud)。注册 Tigris 账户后，创建一个名为 `vectordemo` 的新项目。接下来，记下您创建项目的区域的*Uri*、**clientId** 和 **clientSecret**。您可以在项目的**Application Keys** 部分找到所有这些信息。

# %% [markdown]
# 首先，我们来安装依赖项：

# %%
# %pip install --upgrade --quiet  tigrisdb openapi-schema-pydantic langchain-openai langchain-community tiktoken

# %% [markdown]
# 我们将在环境中加载 `OpenAI` API 密钥和 `Tigris` 凭证

# %%
import getpass
import os

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass("OpenAI API Key:")
if "TIGRIS_PROJECT" not in os.environ:
    os.environ["TIGRIS_PROJECT"] = getpass.getpass("Tigris Project Name:")
if "TIGRIS_CLIENT_ID" not in os.environ:
    os.environ["TIGRIS_CLIENT_ID"] = getpass.getpass("Tigris Client Id:")
if "TIGRIS_CLIENT_SECRET" not in os.environ:
    os.environ["TIGRIS_CLIENT_SECRET"] = getpass.getpass("Tigris Client Secret:")

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import Tigris
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter

# %% [markdown]
# ### 初始化 Tigris 向量存储
# 让我们导入我们的测试数据集：

# %%
loader = TextLoader("../../../state_of_the_union.txt")
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

embeddings = OpenAIEmbeddings()

# %%
vector_store = Tigris.from_documents(docs, embeddings, index_name="my_embeddings")

# %% [markdown]
# ### 相似性搜索
#
# Similarity search is a technique used to find items that are similar to a given query item. It is widely used in various applications such as recommendation systems, image retrieval, and natural language processing.
#
# There are several ways to perform similarity search, depending on the type of data and the desired level of accuracy. Some common methods include:
#
# *   **K-Nearest Neighbors (KNN):** This is a simple and widely used algorithm that finds the *k* items in a dataset that are closest to a given query item. The "closeness" is typically measured using a distance metric, such as Euclidean distance or cosine similarity.
#
# *   **Locality-Sensitive Hashing (LSH):** LSH is a technique that hashes data points in such a way that similar data points are likely to be mapped to the same "buckets." This allows for efficient approximate similarity search, especially in high-dimensional spaces.
#
# *   **Vector Databases:** These databases are specifically designed to store and query high-dimensional vectors, which are often used to represent data in similarity search. They typically employ specialized indexing techniques, such as Approximate Nearest Neighbor (ANN) algorithms, to speed up search operations.
#
# When performing similarity search, it's important to consider the following:
#
# *   **Choice of Similarity Metric:** The metric used to define "similarity" can significantly impact the search results. Common metrics include Euclidean distance, cosine similarity, Jaccard similarity, and Hamming distance. The best choice depends on the nature of the data.
#
# *   **Indexing:** For large datasets, efficient indexing is crucial for fast similarity search. Various indexing structures, such as KD-trees, ball trees, and ANN indexes, can be used to speed up the search process.
#
# *   **Scalability:** As datasets grow, the chosen similarity search method must be able to scale efficiently. This might involve using distributed computing or specialized hardware.
#
# *   **Accuracy vs. Speed Trade-off:** Many approximate similarity search methods offer a trade-off between search speed and accuracy. It's important to choose a method that balances these factors according to the application's requirements.
#
# In summary, similarity search is a powerful technique for finding related items. By carefully selecting the appropriate methods, metrics, and indexing strategies, you can build efficient and effective similarity search systems.
#
# ---
#
# 相似性搜索是一种用于查找与给定查询项相似的项的技术。它广泛应用于推荐系统、图像检索和自然语言处理等各种应用中。
#
# 根据数据的类型和所需的准确性级别，有几种执行相似性搜索的方法。一些常用方法包括：
#
# *   **K-最近邻 (KNN):** 这是一种简单且广泛使用的算法，用于查找数据集中与给定查询项最接近的 *k* 个项。“接近度”通常使用距离度量来衡量，例如欧几里得距离或余弦相似度。
#
# *   **局部敏感哈希 (LSH):** LSH 是一种将数据点哈希化的技术，使得相似的数据点很可能映射到相同的“桶”中。这使得高效的近似相似性搜索成为可能，尤其是在高维空间中。
#
# *   **向量数据库:** 这些数据库专门设计用于存储和查询高维向量，这些向量通常用于在相似性搜索中表示数据。它们通常采用专门的索引技术，例如近似最近邻 (ANN) 算法，来加速搜索操作。
#
# 在执行相似性搜索时，考虑以下几点很重要：
#
# *   **相似性度量选择:** 用于定义“相似性”的度量会对搜索结果产生重大影响。常用度量包括欧几里得距离、余弦相似度、杰卡德相似度（Jaccard similarity）和汉明距离。最佳选择取决于数据的性质。
#
# *   **索引:** 对于大型数据集，高效的索引对于快速相似性搜索至关重要。可以使用各种索引结构，例如 KD 树、球树（ball trees）和 ANN 索引，来加速搜索过程。
#
# *   **可扩展性:** 随着数据集的增长，所选的相似性搜索方法必须能够高效地扩展。这可能涉及使用分布式计算或专用硬件。
#
# *   **准确性与速度的权衡:** 许多近似相似性搜索方法在搜索速度和准确性之间提供了权衡。重要的是选择一种方法，根据应用程序的要求来平衡这些因素。
#
# 总之，相似性搜索是一种查找相关项的强大技术。通过仔细选择适当的方法、度量和索引策略，您可以构建高效且有效的相似性搜索系统。

# %%
query = "What did the president say about Ketanji Brown Jackson"
found_docs = vector_store.similarity_search(query)
print(found_docs)

# %% [markdown]
# ### 相似性搜索（带分数/向量距离）

# %%
query = "What did the president say about Ketanji Brown Jackson"
result = vector_store.similarity_search_with_score(query)
for doc, score in result:
    print(f"document={doc}, score={score}")
