# %% [markdown]
# # OpenSearch
#
# > [OpenSearch](https://opensearch.org/) 是一个可扩展、灵活且可扩展的开源软件套件，用于搜索、分析和可观测性应用程序，根据 Apache 2.0 许可。`OpenSearch` 是一个基于 `Apache Lucene` 的分布式搜索和分析引擎。
#
# 本 Notebook 展示了如何使用与 `OpenSearch` 数据库相关的功能。
#
# 要运行，您应该有一个正在运行的 OpenSearch 实例：[请参阅此处了解简单的 Docker 安装](https://hub.docker.com/r/opensearchproject/opensearch)。
#
# `similarity_search` 默认执行近似 k-NN 搜索，它使用 lucene、nmslib、faiss 等多种算法之一，这些算法推荐用于大型数据集。要执行暴力搜索，我们有其他称为脚本评分 (Script Scoring) 和 Painless 脚本 (Painless Scripting) 的搜索方法。请查看 [此处](https://opensearch.org/docs/latest/search-plugins/knn/index/) 获取更多详细信息。

# %% [markdown]
# ## 安装
# 安装 Python 客户端。

# %%
# %pip install --upgrade --quiet  opensearch-py langchain-community

# %% [markdown]
# 我们想要使用 OpenAIEmbeddings，所以我们需要获取 OpenAI API 密钥。

# %%
import getpass
import os

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass("OpenAI API Key:")

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import OpenSearchVectorSearch
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../../how_to/state_of_the_union.txt")
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

embeddings = OpenAIEmbeddings()

# %% [markdown]
# ## 使用近似 k-NN 进行相似性搜索
#
# 使用具有自定义参数的近似 k-NN 搜索进行 `similarity_search`

# %%
docsearch = OpenSearchVectorSearch.from_documents(
    docs, embeddings, opensearch_url="http://localhost:9200"
)

# If using the default Docker installation, use this instantiation instead:
# docsearch = OpenSearchVectorSearch.from_documents(
#     docs,
#     embeddings,
#     opensearch_url="https://localhost:9200",
#     http_auth=("admin", "admin"),
#     use_ssl = False,
#     verify_certs = False,
#     ssl_assert_hostname = False,
#     ssl_show_warn = False,
# )

# %%
query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.similarity_search(query, k=10)

# %%
print(docs[0].page_content)

# %%
docsearch = OpenSearchVectorSearch.from_documents(
    docs,
    embeddings,
    opensearch_url="http://localhost:9200",
    engine="faiss",
    space_type="innerproduct",
    ef_construction=256,
    m=48,
)

query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.similarity_search(query)

# %%
print(docs[0].page_content)

# %% [markdown]
# ## 使用脚本评分的相似性搜索
#
# 使用自定义参数的 `Script Scoring` 进行 `similarity_search`

# %%
docsearch = OpenSearchVectorSearch.from_documents(
    docs, embeddings, opensearch_url="http://localhost:9200", is_appx_search=False
)

query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.similarity_search(
    "What did the president say about Ketanji Brown Jackson",
    k=1,
    search_type="script_scoring",
)

# %%
print(docs[0].page_content)

# %% [markdown]
# ## 使用 Painless 脚本进行相似性搜索
#
# 使用 Painless 脚本和自定义参数进行 `similarity_search`

# %%
docsearch = OpenSearchVectorSearch.from_documents(
    docs, embeddings, opensearch_url="http://localhost:9200", is_appx_search=False
)
filter = {"bool": {"filter": {"term": {"text": "smuggling"}}}}
query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.similarity_search(
    "What did the president say about Ketanji Brown Jackson",
    search_type="painless_scripting",
    space_type="cosineSimilarity",
    pre_filter=filter,
)

# %%
print(docs[0].page_content)

# %% [markdown]
# ## 最大化边际相关性搜索 (MMR)
# 如果您想查找一些相似的文档，但同时也希望获得多样化的结果，那么 MMR 是您应该考虑的方法。最大化边际相关性在优化与查询的相似性 AND 所选文档之间的多样性。

# %%
query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.max_marginal_relevance_search(query, k=2, fetch_k=10, lambda_param=0.5)

# %% [markdown]
# ## 使用现有的 OpenSearch 实例
#
# 也可以将现有 OpenSearch 实例与已包含向量的文档一起使用。

# %%
# this is just an example, you would need to change these values to point to another opensearch instance
docsearch = OpenSearchVectorSearch(
    index_name="index-*",
    embedding_function=embeddings,
    opensearch_url="http://localhost:9200",
)

# you can specify custom field names to match the fields you're using to store your embedding, document text value, and metadata
docs = docsearch.similarity_search(
    "Who was asking about getting lunch today?",
    search_type="script_scoring",
    space_type="cosinesimil",
    vector_field="message_embedding",
    text_field="message",
    metadata_field="message_metadata",
)

# %% [markdown]
# ## 使用 AOSS (Amazon OpenSearch Service Serverless)
#
# 这是一个使用 `faiss` 引擎和 `efficient_filter` 的 `AOSS` 示例。
#
# 我们需要安装几个 `python` 包。

# %%
# %pip install --upgrade --quiet  boto3 requests requests-aws4auth

# %%
import boto3
from opensearchpy import RequestsHttpConnection
from requests_aws4auth import AWS4Auth

service = "aoss"  # must set the service as 'aoss'
region = "us-east-2"
credentials = boto3.Session(
    aws_access_key_id="xxxxxx", aws_secret_access_key="xxxxx"
).get_credentials()
awsauth = AWS4Auth("xxxxx", "xxxxxx", region, service, session_token=credentials.token)

docsearch = OpenSearchVectorSearch.from_documents(
    docs,
    embeddings,
    opensearch_url="host url",
    http_auth=awsauth,
    timeout=300,
    use_ssl=True,
    verify_certs=True,
    connection_class=RequestsHttpConnection,
    index_name="test-index-using-aoss",
    engine="faiss",
)

docs = docsearch.similarity_search(
    "What is feature selection",
    efficient_filter=filter,
    k=200,
)

# %% [markdown]
# ## 使用 AOS (Amazon OpenSearch Service)
#
# Amazon OpenSearch Service (AOS) 是一个托管服务，可以轻松地在 AWS 上部署、操作和扩展 OpenSearch 集群。OpenSearch 是一个开源的分布式搜索和分析套件，源自 Elasticsearch 和 Kibana。
#
# AOS 提供以下优势：
#
# *   **易于部署和管理：** AWS 负责集群的配置、补丁和备份，让您可以专注于应用程序。
# *   **可扩展性：** 您可以根据需求轻松地扩展或缩减集群的计算和存储资源。
# *   **高可用性：** AOS 提供跨多个可用区的冗余，以实现高可用性。
# *   **安全性：** AOS 集成了 AWS Identity and Access Management (IAM) 和 VPC，以提供强大的安全控制。
# *   **与其他 AWS 服务的集成：** AOS 可以轻松地与其他 AWS 服务（如 Amazon S3、AWS Lambda 和 Amazon CloudWatch）集成。
#
# ### 核心概念
#
# *   **域 (Domain)：** 指一个 OpenSearch 集群。您可以创建多个域来隔离不同的工作负载或环境。
# *   **节点 (Node)：** 指集群中的一台服务器。OpenSearch 集群由一个或多个节点组成。
# *   **索引 (Index)：** 指一个存储相关文档的集合。类似于关系数据库中的表。
# *   **文档 (Document)：** 指存储在索引中的基本信息单元。通常是 JSON 格式。
# *   **分片 (Shard)：** 指索引的子集。为了提高性能和可扩展性，索引会被分成一个或多个分片。
# *   **副本 (Replica)：** 指分片的副本。用于提高数据的可用性和读取性能。
# *   **节点角色 (Node Roles)：** OpenSearch 中的节点可以承担不同的角色，如主节点 (master-eligible)、数据节点 (data) 和协调节点 (coordinating)。AOS 会自动管理这些角色的分配。
#
# ### 部署 AOS 集群
#
# 1.  **登录 AWS 管理控制台** 并导航到 **Amazon OpenSearch Service**。
# 2.  点击 **创建域**。
# 3.  **配置域：**
#     *   **域名称：** 为您的域指定一个唯一的名称。
#     *   **节点类型：** 选择您需要的节点类型（如通用型、内存优化型等）和实例大小。
#     *   **实例数量：** 指定集群中的节点数量。
#     *   **存储配置：** 选择实例存储或 Amazon EBS 卷，并配置存储大小。
#     *   **网络配置：** 选择 VPC 和子网，以控制对集群的访问。
#     *   **访问策略：** 配置允许访问集群的 IAM 策略。您可以选择公开访问或限制为特定 IP 地址或 VPC。
#     *   **其他设置：** 根据需要配置日志记录、加密、版本等。
# 4.  点击 **创建域**。
#
# 部署过程可能需要一些时间，具体取决于您选择的配置。
#
# ### 连接到 AOS 集群
#
# 部署完成后，您可以通过以下方式连接到您的 AOS 集群：
#
# *   **使用 OpenSearch Dashboards：** AOS 会自动为您部署一个 OpenSearch Dashboards 实例。您可以在域详情页面找到其 URL。OpenSearch Dashboards 是一个用于可视化和探索 OpenSearch 数据的 Web 界面。
# *   **使用 cURL 或其他 HTTP 客户端：** 您可以使用 cURL 或其他 HTTP 客户端向集群的端点发送请求。您需要使用您的 AWS 凭证对请求进行签名。
# *   **使用 OpenSearch 客户端库：** OpenSearch 提供了多种语言的客户端库（如 Python、Java、JavaScript），可以方便地与集群进行交互。
#
# ### 示例：使用 cURL 索引和搜索文档
#
# 假设您的 AOS 集群端点是 `https://search-my-domain-xxxxxxxxxx.us-east-1.es.amazonaws.com`。
#
# **1. 索引一个文档：**
#
# ```bash
# curl -X PUT "https://search-my-domain-xxxxxxxxxx.us-east-1.es.amazonaws.com/my-index/_doc/1" -H "Content-Type: application/json" -d'
# {
#   "title": "Learning OpenSearch",
#   "content": "This is the first document about OpenSearch."
# }
# '
# ```
#
# **2. 搜索文档：**
#
# ```bash
# curl -X GET "https://search-my-domain-xxxxxxxxxx.us-east-1.es.amazonaws.com/my-index/_search" -H "Content-Type: application/json" -d'
# {
#   "query": {
#     "match": {
#       "content": "OpenSearch"
#     }
#   }
# }
# '
# ```
#
# **注意：** 在实际使用中，您需要对这些请求进行 AWS 签名。可以使用 AWS CLI 或相应的 SDK 来简化签名过程。
#
# ### 监控和管理
#
# AOS 与 Amazon CloudWatch 集成，您可以监控集群的性能指标，如 CPU 使用率、内存使用率、磁盘 I/O 等。您还可以配置告警，以便在出现问题时收到通知。
#
# 您可以通过 AWS 管理控制台来管理您的 AOS 域，包括：
#
# *   修改实例类型和数量
# *   调整存储配置
# *   更新访问策略
# *   管理快照和恢复
# *   查看日志和指标
#
# ### 总结
#
# Amazon OpenSearch Service 提供了一种便捷的方式来部署和管理 OpenSearch 集群。通过理解其核心概念并利用 AWS 提供的工具，您可以有效地利用 OpenSearch 进行搜索、分析和可视化数据。

# %%
# %pip install --upgrade --quiet  boto3

# %%
# This is just an example to show how to use Amazon OpenSearch Service, you need to set proper values.
import boto3
from opensearchpy import RequestsHttpConnection

service = "es"  # must set the service as 'es'
region = "us-east-2"
credentials = boto3.Session(
    aws_access_key_id="xxxxxx", aws_secret_access_key="xxxxx"
).get_credentials()
awsauth = AWS4Auth("xxxxx", "xxxxxx", region, service, session_token=credentials.token)

docsearch = OpenSearchVectorSearch.from_documents(
    docs,
    embeddings,
    opensearch_url="host url",
    http_auth=awsauth,
    timeout=300,
    use_ssl=True,
    verify_certs=True,
    connection_class=RequestsHttpConnection,
    index_name="test-index",
)

docs = docsearch.similarity_search(
    "What is feature selection",
    k=200,
)
