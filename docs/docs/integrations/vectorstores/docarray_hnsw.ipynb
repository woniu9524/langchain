# %% [markdown]
# # DocArray HnswSearch
#
# >[DocArrayHnswSearch](https://docs.docarray.org/user_guide/storing/index_hnswlib/) 是 [Docarray](https://github.com/docarray/docarray) 提供的一个轻量级 Document Index 实现，完全在本地运行，最适合中小型数据集。它将向量存储在磁盘上的 [hnswlib](https://github.com/nmslib/hnswlib) 中，并将所有其他数据存储在 [SQLite](https://www.sqlite.org/index.html) 中。
#
# 您需要安装 `langchain-community` 才能使用此集成：`pip install -qU langchain-community`
#
# 本笔记本展示了如何使用与 `DocArrayHnswSearch` 相关的函数。

# %% [markdown]
# ## 设置
#
# 如果您尚未安装 DocArray 或设置 OpenAI API 密钥，请取消注释以下单元格以进行安装和设置。

# %%
# %pip install --upgrade --quiet  "docarray[hnswlib]"

# %%
# Get an OpenAI token: https://platform.openai.com/account/api-keys

# import os
# from getpass import getpass

# OPENAI_API_KEY = getpass()

# os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %% [markdown]
# ## 使用 DocArrayHnswSearch
#
# DocArrayHnswSearch 是一个用于高效相似性搜索的向量数据库。它基于 Hierarchical Navigable Small Worlds (HNSW) 算法，该算法以其速度和准确性而闻名。
#
# ### 安装
#
# 您可以使用 pip 安装 DocArrayHnswSearch：
#
# ```bash
# pip install docarray-hnswsearch
# ```
#
# ### 基本用法
#
# 以下是如何使用 DocArrayHnswSearch 的基本示例：
#
# ```python
# from docarray import Document, DocumentArray
# from docarray_hnswsearch import DocArrayHnswSearch
#
# # 创建一个 DocumentArray
# docs = DocumentArray([
#     Document(id='doc1', vector=[1, 2, 3]),
#     Document(id='doc2', vector=[4, 5, 6]),
#     Document(id='doc3', vector=[7, 8, 9])
# ])
#
# # 初始化 HNSW 索引
# # M 是 HNSW 图中的邻居数量，ef_construction 是构建索引时的搜索范围
# index = DocArrayHnswSearch(docs, M=16, ef_construction=64)
#
# # 添加文档到索引
# index.add(docs)
#
# # 进行相似性搜索
# # ef 是搜索时的搜索范围，k 是返回的最近邻数量
# query_vector = [1, 1, 1]
# results = index.search(query_vector, ef=64, k=2)
#
# # 打印搜索结果
# for res in results:
#     print(f"ID: {res.id}, Score: {res.score}")
# ```
#
# ### 参数详解
#
# *   **`docs`**: 要索引的 `DocumentArray`。
# *   **`M`**: HNSW 图中的邻居数量。值越高，索引构建时间越长，但搜索精度越高。
# *   **`ef_construction`**: 构建索引时的搜索范围。值越高，索引构建时间越长，但索引质量越高。
# *   **`ef`**: 进行搜索时的搜索范围。值越高，搜索时间越长，但搜索精度越高。
# *   **`k`**: 返回的最近邻数量。
#
# ### 高级用法
#
# #### 增量添加
#
# 您可以逐个或批量添加文档到现有索引：
#
# ```python
# # 添加单个文档
# new_doc = Document(id='doc4', vector=[2, 3, 4])
# index.add(new_doc)
#
# # 添加多个文档
# new_docs = DocumentArray([
#     Document(id='doc5', vector=[5, 6, 7]),
#     Document(id='doc6', vector=[8, 9, 10])
# ])
# index.add(new_docs)
# ```
#
# #### 删除文档
#
# 您可以根据文档 ID 删除文档：
#
# ```python
# index.delete(['doc1'])
# ```
#
# #### 更新文档
#
# 更新文档需要先删除再添加：
#
# ```python
# # 更新 doc2
# index.delete(['doc2'])
# updated_doc2 = Document(id='doc2', vector=[10, 11, 12])
# index.add(updated_doc2)
# ```
#
# #### 保存和加载索引
#
# 您可以将索引保存到磁盘，并在以后加载它：
#
# ```python
# # 保存索引
# index.save('my_hnsw_index')
#
# # 加载索引
# loaded_index = DocArrayHnswSearch.load('my_hnsw_index')
# ```
#
# #### 配置参数
#
# 您可以在初始化时配置更多 HNSW 参数：
#
# ```python
# index = DocArrayHnswSearch(
#     docs,
#     M=32,
#     ef_construction=128,
#     ef=128,
#     distance='cosine' # 支持 'l2' (欧氏距离) 和 'cosine' (余弦相似度)
# )
# ```
#
# ### 性能优化
#
# *   **`M` 和 `ef_construction`**: 调整这些参数以在索引构建时间和搜索性能之间取得平衡。
# *   **`ef`**: 在搜索时，增加 `ef` 可以提高精度，但会增加搜索时间。
# *   **向量维度**: HNSW 在低到中等维度（通常高达几百维）上表现最佳。对于非常高维的数据，可能需要降维技术。
# *   **硬件**: 更多的 RAM 和更快的 CPU 会显著提高性能。
#
# ### 总结
#
# DocArrayHnswSearch 提供了一种简单而强大的方式来构建和查询向量索引。通过调整其参数，您可以根据您的具体需求优化性能和精度。

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import DocArrayHnswSearch
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter

# %%
documents = TextLoader("../../how_to/state_of_the_union.txt").load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

embeddings = OpenAIEmbeddings()

db = DocArrayHnswSearch.from_documents(
    docs, embeddings, work_dir="hnswlib_store/", n_dim=1536
)

# %% [markdown]
# ### 相似性搜索
#
# Similarity search is a technique used to find items that are similar to a given query item. This is often used in applications such as recommendation systems, image retrieval, and natural language processing.
#
# 相似性搜索是一种用于查找与给定查询项相似的项的技术。这通常用于推荐系统、图像检索和自然语言处理等应用程序中。
#
# There are many different algorithms and techniques for performing similarity search, depending on the type of data and the desired level of accuracy. Some common approaches include:
#
# 根据数据的类型和所需的准确性级别，有许多不同的算法和技术用于执行相似性搜索。一些常见的方法包括：
#
# *   **K-Nearest Neighbors (KNN):** This is a simple and widely used algorithm that finds the K items in a dataset that are closest to the query item, based on a chosen distance metric.
#
#     *   **K-近邻 (KNN):** 这是一种简单且广泛使用的算法，它根据选定的距离度量，在数据集中查找与查询项最接近的 K 个项。
#
# *   **Locality-Sensitive Hashing (LSH):** LSH is a technique that hashes items in such a way that similar items are likely to end up in the same "bucket" or have the same hash value. This allows for faster searching by only comparing items within the same bucket.
#
#     *   **局部敏感哈希 (LSH):** LSH 是一种对项进行哈希处理的技术，使得相似的项很可能落在同一个“桶”中或具有相同的哈希值。通过仅比较同一桶中的项，这可以实现更快的搜索。
#
# *   **Vector Embeddings:** In many modern applications, items are represented as dense vectors in a high-dimensional space. Similarity search then involves finding vectors that are close to the query vector in this space, often using metrics like cosine similarity or Euclidean distance. Libraries like FAISS, Annoy, and ScaNN are popular for efficient vector similarity search.
#
#     *   **向量嵌入:** 在许多现代应用程序中，项在高维空间中表示为密集向量。相似性搜索然后涉及在该空间中查找与查询向量接近的向量，通常使用余弦相似度或欧几里得距离等度量。FAISS、Annoy 和 ScaNN 等库在高效向量相似性搜索方面很受欢迎。
#
# *   **Tree-based methods:** Structures like KD-trees or Ball trees can be used to organize data points in a way that allows for efficient nearest neighbor searches.
#
#     *   **基于树的方法:** 像 KD 树或球树这样的结构可用于组织数据点，从而能够高效地进行最近邻搜索。
#
# The choice of similarity search method depends on factors such as the size of the dataset, the dimensionality of the data, the desired speed and accuracy trade-off, and the specific distance metric being used.
#
# 相似性搜索方法的选择取决于数据集的大小、数据的维度、所需的速度和准确性权衡以及所使用的特定距离度量等因素。

# %%
query = "What did the president say about Ketanji Brown Jackson"
docs = db.similarity_search(query)

# %%
print(docs[0].page_content)
# Out:
# Tonight. I call on the Senate to: Pass the Freedom to Vote Act. Pass the John Lewis Voting Rights Act. And while you’re at it, pass the Disclose Act so Americans can know who is funding our elections.
#
# Tonight, I’d like to honor someone who has dedicated his life to serve this country: Justice Stephen Breyer—an Army veteran, Constitutional scholar, and retiring Justice of the United States Supreme Court. Justice Breyer, thank you for your service.
#
# One of the most serious constitutional responsibilities a President has is nominating someone to serve on the United States Supreme Court.
#
# And I did that 4 days ago, when I nominated Circuit Court of Appeals Judge Ketanji Brown Jackson. One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence.

# %% [markdown]
# ### 相似度搜索与评分
#
# Similarity search is a common task in many applications, such as recommendation systems, image retrieval, and natural language processing. It involves finding items in a dataset that are most similar to a given query item.
#
# 相似度搜索在许多应用中是一项常见任务，例如推荐系统、图像检索和自然语言处理。它涉及在数据集中查找与给定查询项最相似的项。
#
# The similarity between two items is typically measured by a similarity score. A higher score indicates greater similarity.
#
# 两个项之间的相似度通常通过相似度评分来衡量。评分越高表示相似度越大。
#
# Here's how you can perform similarity search with scores in a vector database:
#
# 以下是在向量数据库中执行带评分的相似度搜索的方法：
#
# **1. Define your data and similarity metric**
#
# **1. 定义您的数据和相似度指标**
#
# First, you need to represent your data as vectors. Each vector will correspond to an item in your dataset. You also need to choose a similarity metric, such as cosine similarity, dot product, or Euclidean distance.
#
# 首先，您需要将数据表示为向量。每个向量将对应数据集中的一个项。您还需要选择一个相似度指标，例如余弦相似度、点积或欧氏距离。
#
# **2. Index your data**
#
# **2. 索引您的数据**
#
# Once your data is vectorized, you need to index it in the vector database. This allows for efficient searching. The indexing process typically involves building a data structure (e.g., an HNSW graph) that enables fast nearest neighbor searches.
#
# 一旦您的数据被向量化，您就需要将其索引到向量数据库中。这可以实现高效搜索。索引过程通常涉及构建一个数据结构（例如 HNSW 图），该结构能够实现快速的最近邻搜索。
#
# **3. Perform a similarity search**
#
# **3. 执行相似度搜索**
#
# To perform a similarity search, you provide a query vector and specify the number of nearest neighbors you want to retrieve. The database will then return the items that are most similar to your query vector, along with their similarity scores.
#
# 要执行相似度搜索，您需要提供一个查询向量，并指定要检索的最近邻的数量。然后，数据库将返回与您的查询向量最相似的项，以及它们的相似度评分。
#
# Here's an example using Python and a hypothetical vector database client:
#
# 以下是使用 Python 和一个假设的向量数据库客户端的示例：
#
# ```python
# # Assume 'db_client' is an initialized client for your vector database
# # 假设 'db_client' 是您向量数据库的已初始化客户端
#
# query_vector = [0.1, 0.5, -0.2, 0.8]
# top_k = 5
#
# # Perform the similarity search
# # 执行相似度搜索
# results = db_client.search(vector=query_vector, k=top_k)
#
# # Print the results with scores
# # 打印带评分的结果
# for item in results:
#     print(f"Item ID: {item['id']}, Similarity Score: {item['score']}")
# ```
#
# In this example:
#
# 在此示例中：
#
# - `query_vector` is the vector representation of the item you want to find similar items for.
# - `query_vector` 是您要查找相似项的项的向量表示。
# - `top_k` specifies that you want to retrieve the top 5 most similar items.
# - `top_k` 指定您希望检索最相似的 5 个项。
# - The `db_client.search()` method returns a list of dictionaries, where each dictionary contains the ID of a similar item and its corresponding similarity score.
# - `db_client.search()` 方法返回一个字典列表，其中每个字典包含相似项的 ID 及其相应的相似度评分。
#
# **Interpreting the scores**
#
# **解释评分**
#
# The interpretation of the similarity scores depends on the chosen similarity metric:
#
# 相似度评分的解释取决于所选的相似度指标：
#
# - **Cosine Similarity:** Scores range from -1 to 1. A score of 1 means the vectors are identical in direction, 0 means they are orthogonal, and -1 means they are diametrically opposed. For most similarity search use cases, you'll be interested in scores closer to 1.
# - **余弦相似度：** 评分范围从 -1 到 1。得分为 1 表示向量方向相同，得分为 0 表示它们正交，得分为 -1 表示它们方向相反。对于大多数相似度搜索用例，您会关注接近 1 的评分。
# - **Dot Product:** The range of scores depends on the magnitude of the vectors. Higher positive scores indicate greater similarity.
# - **点积：** 评分的范围取决于向量的幅度。较高的正分数表示较高的相似度。
# - **Euclidean Distance:** Scores represent the distance between two vectors in the vector space. Lower scores indicate greater similarity (i.e., the vectors are closer together). Note that some vector databases might return a "dissimilarity" score for Euclidean distance, where lower is better.
# - **欧氏距离：** 评分表示向量空间中两个向量之间的距离。较低的评分表示较高的相似度（即向量靠得更近）。请注意，一些向量数据库可能会为欧氏距离返回“不相似度”评分，其中较低的值更好。
#
# By understanding the similarity scores, you can effectively rank and filter the search results to find the most relevant items for your application.
#
# 通过理解相似度评分，您可以有效地对搜索结果进行排名和过滤，从而为您的应用程序找到最相关的项。

# %% [markdown]
# 返回的距离分数是余弦距离。因此，分数越低越好。

# %%
docs = db.similarity_search_with_score(query)

# %%
docs[0]
# Out:
# (Document(page_content='Tonight. I call on the Senate to: Pass the Freedom to Vote Act. Pass the John Lewis Voting Rights Act. And while you’re at it, pass the Disclose Act so Americans can know who is funding our elections. \n\nTonight, I’d like to honor someone who has dedicated his life to serve this country: Justice Stephen Breyer—an Army veteran, Constitutional scholar, and retiring Justice of the United States Supreme Court. Justice Breyer, thank you for your service. \n\nOne of the most serious constitutional responsibilities a President has is nominating someone to serve on the United States Supreme Court. \n\nAnd I did that 4 days ago, when I nominated Circuit Court of Appeals Judge Ketanji Brown Jackson. One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence.', metadata={}),
#  0.36962226)

# %%
import shutil

# delete the dir
shutil.rmtree("hnswlib_store")
