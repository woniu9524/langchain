# %% [markdown]
# # scikit-learn
#
# >[scikit-learn](https://scikit-learn.org/stable/) 是一个开源的机器学习算法集合，包括一些 [k 近邻](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.NearestNeighbors.html) 的实现。`SKLearnVectorStore` 封装了此实现，并增加了以 json、bson（二进制 json）或 Apache Parquet 格式持久化向量存储的可能性。
#
# 本笔记本展示了如何使用 `SKLearnVectorStore` 向量数据库。
#
# 您需要安装 `langchain-community` (`pip install -qU langchain-community`) 才能使用此集成。

# %%
# %pip install --upgrade --quiet  scikit-learn

# # if you plan to use bson serialization, install also:
# %pip install --upgrade --quiet  bson

# # if you plan to use parquet serialization, install also:
# %pip install --upgrade --quiet  pandas pyarrow

# %% [markdown]
# 要使用 OpenAI 嵌入，您需要一个 OpenAI 密钥。您可以在 https://platform.openai.com/account/api-keys 获取一个，或者随意使用任何其他嵌入。

# %%
import os
from getpass import getpass

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI key:")

# %% [markdown]
# ## 基本用法
#
# ### 加载示例文档语料库

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import SKLearnVectorStore
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter

loader = TextLoader("../../how_to/state_of_the_union.txt")
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)
embeddings = OpenAIEmbeddings()

# %% [markdown]
# ### 创建 SKLearnVectorStore，索引文档语料库并运行示例查询
#
# This notebook demonstrates how to create a `SKLearnVectorStore` and index a document corpus.
#
# 本笔记本演示了如何创建 `SKLearnVectorStore` 并索引文档语料库。
#
# First, let's set up the environment by importing the necessary libraries.
#
# 首先，让我们通过导入必要的库来设置环境。
#
# ```python
# from langchain_community.vectorstores import SKLearnVectorStore
# from langchain_community.embeddings.sentence_transformer import (
#     SentenceTransformerEmbeddings,
# )
# from langchain_core.documents import Document
#
# # Define the embedding model
# # 定义嵌入模型
# embedding_model = SentenceTransformerEmbeddings(model_name="all-MiniLM-6-v2")
# ```
#
# Next, we'll create a sample document corpus. This corpus consists of a list of `Document` objects, each containing a page content and optional metadata.
#
# 接下来，我们将创建一个示例文档语料库。该语料库包含一个 `Document` 对象列表，每个对象都包含页面内容和可选的元数据。
#
# ```python
# # Create a sample document corpus
# # 创建示例文档语料库
# documents = [
#     Document(page_content="This is the first document."),
#     Document(page_content="This document is the second document."),
#     Document(page_content="And this is the third one."),
#     Document(page_content="Is this the first document?", metadata={"source": "doc1"}),
#     Document(page_content="Which is the second document?", metadata={"source": "doc2"}),
#     Document(page_content="This is the third document, yes.", metadata={"source": "doc3"}),
# ]
# ```
#
# Now, we can create the `SKLearnVectorStore` by passing the documents and the embedding model to its constructor.
#
# 现在，我们可以通过将文档和嵌入模型传递给其构造函数来创建 `SKLearnVectorStore`。
#
# ```python
# # Create the SKLearnVectorStore
# # 创建 SKLearnVectorStore
# vector_store = SKLearnVectorStore(documents=documents, embedding=embedding_model)
# ```
#
# Once the vector store is created, we can index the document corpus. The `add_documents` method handles this process.
#
# 创建向量存储后，我们可以索引文档语料库。`add_documents` 方法处理此过程。
#
# ```python
# # Index the document corpus
# # 索引文档语料库
# vector_store.add_documents(documents)
# ```
#
# Finally, let's run a sample query to retrieve the most similar documents from the indexed corpus.
#
# 最后，让我们运行一个示例查询，从索引的语料库中检索最相似的文档。
#
# ```python
# # Run a sample query
# # 运行示例查询
# query = "This is a test query."
# # Retrieve the most similar documents
# # 检索最相似的文档
# results = vector_store.similarity_search(query)
#
# # Print the results
# # 打印结果
# for doc in results:
#     print(doc)

# %%
import tempfile

persist_path = os.path.join(tempfile.gettempdir(), "union.parquet")

vector_store = SKLearnVectorStore.from_documents(
    documents=docs,
    embedding=embeddings,
    persist_path=persist_path,  # persist_path and serializer are optional
    serializer="parquet",
)

query = "What did the president say about Ketanji Brown Jackson"
docs = vector_store.similarity_search(query)
print(docs[0].page_content)
# Out:
# Tonight. I call on the Senate to: Pass the Freedom to Vote Act. Pass the John Lewis Voting Rights Act. And while you’re at it, pass the Disclose Act so Americans can know who is funding our elections.
#
# Tonight, I’d like to honor someone who has dedicated his life to serve this country: Justice Stephen Breyer—an Army veteran, Constitutional scholar, and retiring Justice of the United States Supreme Court. Justice Breyer, thank you for your service.
#
# One of the most serious constitutional responsibilities a President has is nominating someone to serve on the United States Supreme Court.
#
# And I did that 4 days ago, when I nominated Circuit Court of Appeals Judge Ketanji Brown Jackson. One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence.

# %% [markdown]
# ## 保存和加载向量存储
#
# You can save and load a vector store to and from disk. This is useful for persisting your vector store between sessions or for sharing it with others.
#
# 您可以将向量存储保存到磁盘或从磁盘加载。这对于在会话之间持久化您的向量存储或与他人共享它非常有用。
#
# ```python
# from langchain.vectorstores import Chroma
# from langchain.embeddings import OpenAIEmbeddings
#
# # Assume you have a vector store already created
# # For example:
# # from langchain.document_loaders import TextLoader
# # loader = TextLoader("../../modules/state_of_union.txt")
# # documents = loader.load()
# # embeddings = OpenAIEmbeddings()
# # vectorstore = Chroma.from_documents(documents, embeddings)
#
# # Save the vector store to disk
# vectorstore.save_local("my_vector_store")
#
# # Load the vector store from disk
# loaded_vectorstore = Chroma(persist_directory="my_vector_store", embedding_function=OpenAIEmbeddings())
#
# # Now you can use loaded_vectorstore just like the original vectorstore
# # For example:
# # query = "What is the capital of France?"
# # docs = loaded_vectorstore.similarity_search(query)
# # print(docs[0].page_content)
# ```
#
# {/* 假设您已经创建了一个向量存储 */}
# {/* 例如： */}
# {/* from langchain.document_loaders import TextLoader */}
# {/* loader = TextLoader("../../modules/state_of_union.txt") */}
# {/* documents = loader.load() */}
# {/* embeddings = OpenAIEmbeddings() */}
# {/* vectorstore = Chroma.from_documents(documents, embeddings) */}
#
# {/* 将向量存储保存到磁盘 */}
# vectorstore.save_local("my_vector_store")
#
# {/* 从磁盘加载向量存储 */}
# loaded_vectorstore = Chroma(persist_directory="my_vector_store", embedding_function=OpenAIEmbeddings())
#
# {/* 现在您可以使用 loaded_vectorstore 就像使用原始的 vectorstore 一样 */}
# {/* 例如： */}
# {/* query = "What is the capital of France?" */}
# {/* docs = loaded_vectorstore.similarity_search(query) */}
# {/* print(docs[0].page_content) */}

# %%
vector_store.persist()
print("Vector store was persisted to", persist_path)
# Out:
# Vector store was persisted to /var/folders/6r/wc15p6m13nl_nl_n_xfqpc5c0000gp/T/union.parquet

# %%
vector_store2 = SKLearnVectorStore(
    embedding=embeddings, persist_path=persist_path, serializer="parquet"
)
print("A new instance of vector store was loaded from", persist_path)
# Out:
# A new instance of vector store was loaded from /var/folders/6r/wc15p6m13nl_nl_n_xfqpc5c0000gp/T/union.parquet

# %%
docs = vector_store2.similarity_search(query)
print(docs[0].page_content)
# Out:
# Tonight. I call on the Senate to: Pass the Freedom to Vote Act. Pass the John Lewis Voting Rights Act. And while you’re at it, pass the Disclose Act so Americans can know who is funding our elections.
#
# Tonight, I’d like to honor someone who has dedicated his life to serve this country: Justice Stephen Breyer—an Army veteran, Constitutional scholar, and retiring Justice of the United States Supreme Court. Justice Breyer, thank you for your service.
#
# One of the most serious constitutional responsibilities a President has is nominating someone to serve on the United States Supreme Court.
#
# And I did that 4 days ago, when I nominated Circuit Court of Appeals Judge Ketanji Brown Jackson. One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence.

# %% [markdown]
# ## 清理

# %%
os.remove(persist_path)
